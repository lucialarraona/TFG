# %% [markdown]
# # Análisis exploratorio del Dataset Amazon Reviews

# %% [markdown]
# ## Training Dataset English

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load data 
path = "/content/drive/MyDrive/TFG/Datasets_procesados_2/train/amazonEN_train.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#     review_id  ... product_category_cod
# 0  en_0522546  ...                   17
# 1  en_0612910  ...                    0
# 2  en_0983065  ...                   16
# 3  en_0206761  ...                   14
# 4  en_0510474  ...                   24
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   review_id             200000 non-null  object
#  1   product_id            200000 non-null  object
#  2   reviewer_id           200000 non-null  object
#  3   star_rating           200000 non-null  int64
#  4   review_body           200000 non-null  object
#  5   review_title          199977 non-null  object
#  6   language              200000 non-null  object
#  7   product_category      200000 non-null  object
#  8   text_title            200000 non-null  object
#  9   text_title_cat        200000 non-null  object
#  10  text_cat              200000 non-null  object
#  11  product_category_cod  200000 non-null  int64
# dtypes: int64(2), object(10)
# memory usage: 18.3+ MB

# %%
df.shape
# Out:
# (200000, 12)

# %%
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
#sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
sns.set_palette(sns.color_palette("husl", 9)) ## no se cambia??

# %%
## STAR_RATING
sns.countplot(df.star_rating)
plt.xlabel('review stars');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import plotly.express as px
df = px.data.gapminder().query("country == 'Canada'")
fig = px.bar(data_canada, x='year', y='pop')
fig.show()

# %%
sns.countplot(df.product_category)
plt.xlabel('product category');
plt.xticks(rotation=90)

from pylab import rcParams
rcParams['figure.figsize'] = 35, 5
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['review_body'].astype(str)
# Out:
# 0         Not strong enough to run a small 120v vacuum c...
# 1         The leg openings are a little small, but other...
# 2         Really cute mug. I would have given 5 stars if...
# 3         Well it’s looks and feels okay but it most cer...
# 4         Very, very thin, you can bend them with you fi...
#                                 ...
# 199995    Love the jacket which I will wear under a wind...
# 199996                          This item is cheap quality.
# 199997    This has been great for our son and his weekly...
# 199998    I was looking for a relatively cheap but decen...
# 199999                             useful but too expensive
# Name: review_body, Length: 200000, dtype: object

# %%
len_body = df['review_body'].str.len()
len_title = df['review_title'].str.len()

# %%
sns.distplot(len_body)
rcParams['figure.figsize'] = 10, 5
plt.xlim([0, 700]);
plt.xlabel('review length');
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(len_title)
rcParams['figure.figsize'] = 10, 5
plt.xlim([0, 200]);
plt.xlabel('review title');
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['len_body'] = df['review_body'].str.len()
df['len_title'] = df['review_title'].str.len()

# %%
df.head(1)
# Out:
#     review_id          product_id  ... len_body  len_title
# 0  en_0522546  product_en_0681589  ...       67       56.0
#
# [1 rows x 14 columns]

# %%
sns.set(style='darkgrid', palette='muted', font_scale=1.2)
sns.displot(df, x="len_body", hue="star_rating",kind="kde",fill=True, color='blue')
plt.xlim([0, 500]);

# %%
sns.set(style='darkgrid', palette='muted', font_scale=1.2)
sns.displot(df, x="product_category_cod", hue="star_rating",kind="kde",color='green')
plt.xlim([-1, 32]);

# %%
fig = plt.figure(figsize = (15, 6))

sns.distplot(df['len_body'][df['star_rating']==0], color='g', label = '0')
sns.distplot(df['len_body'][df['star_rating']==1], color='r', label = '1')
sns.distplot(df['len_body'][df['star_rating']==2], color='b', label = '2')
sns.distplot(df['len_body'][df['star_rating']==3], color='darkblue', label = '3')
sns.distplot(df['len_body'][df['star_rating']==4], color='yellow', label = '4')


plt.legend(loc='best')
plt.xlabel('Number of Words')
plt.ylabel('Density')
plt.title('The Distribution of Number of Words for each Class (0-4)', fontsize = 14)
plt.xlim([-100, 1000]);
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.catplot(y="product_category", hue="star_rating", kind="count",
            palette="pastel", edgecolor=".6",
            data=df,size= 20)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3747: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
## Correlacion entre los datos?
df.corr()
# Out:
#                       star_rating  product_category_cod  len_body  len_title
# star_rating              1.000000             -0.035907 -0.038379  -0.045136
# product_category_cod    -0.035907              1.000000  0.012312   0.024025
# len_body                -0.038379              0.012312  1.000000   0.278920
# len_title               -0.045136              0.024025  0.278920   1.000000

# %%
# Increase the size of the heatmap.
plt.figure(figsize=(10, 6))
plt.xticks(rotation=90)
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True,cmap='BrBG')
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);
