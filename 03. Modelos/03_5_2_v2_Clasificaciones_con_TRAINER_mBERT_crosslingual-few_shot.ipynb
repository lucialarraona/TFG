# %% [markdown]
# # Librerias

# %%
import torch
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Thu Apr 15 09:49:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           On   | 00000001:00:00.0 Off |                    0 |
# | N/A   56C    P0    56W / 149W |   1846MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla K80           On   | 00000002:00:00.0 Off |                    0 |
# | N/A   43C    P8    34W / 149W |      3MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     73519      C   ...s/py37_pytorch/bin/python     1841MiB |
# +-----------------------------------------------------------------------------+

# %%
# %%capture 
# !pip install transformers -U
#!pip install pytorch

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.5.1
# Summary: State-of-the-art Natural Language Processing for TensorFlow 2.0 and PyTorch
# Home-page: https://github.com/huggingface/transformers
# Author: Thomas Wolf, Lysandre Debut, Victor Sanh, Julien Chaumond, Sam Shleifer, Patrick von Platen, Sylvain Gugger, Google AI Language Team Authors, Open AI team Authors, Facebook AI Authors, Carnegie Mellon University Authors
# Author-email: thomas@huggingface.co
# License: Apache
# Location: /anaconda/envs/py37_pytorch/lib/python3.7/site-packages
# Requires: tokenizers, regex, requests, filelock, sacremoses, packaging, tqdm, numpy, importlib-metadata
# Required-by: bertviz

# %%
from sklearn.model_selection import train_test_split
import torch

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %%capture
# !pip install wandb
import wandb
wandb.login()

# %%
wandb.login()
# Out:
# True

# %% [markdown]
# # Carga de datos
# - incluidas nuevas columnas con concatenacion de review_body y categoria, review_body y titulo
# - nuevos indices para star rating, de 0-4 en vez de 1-5
# - numericalizar las categorias de los productos, 31 en total
#
# Para TRAIN:
#   - data ingles EN
#   - data aleman DE
#
# Para VALID Y TEST:
#   - data en ingles EN
#   - data en aleman DE
#   - data en español ES
#   - data en francés FR
#   - data en japones JA
#   - data en chino ZH

# %%
# Load data
import pandas as pd

## Para TRAIN, en ingles
path1 = "few_shot_FR.csv"

## Para VALID, en ingles
path2 = "amazonEN_valid.csv"


## Para TEST, en ingles, aleman, español, frances, japones y chino
path3 = "amazonFR_test.csv"

####### CONVERTIMOS A DATAFRAMES #########

df_train = pd.read_csv(path1)
df_train = df_train

df_valid = pd.read_csv(path2)
df_valid = df_valid

df_test = pd.read_csv(path3)
df_test = df_test

# %%
df_train.tail(1)
# Out:
#          review_id          product_id          reviewer_id  star_rating  \
# 200999  fr_0680833  product_fr_0533305  reviewer_fr_0485280            2
#
#                                               review_body  \
# 200999  Fonctionne bien. Mais autonomie très faible. C...
#
#                        review_title language product_category  \
# 200999  Bonne tablette pour le prix       fr               pc
#
#                                                text_title  \
# 200999  Bonne tablette pour le prix Fonctionne bien. M...
#
#                                            text_title_cat  \
# 200999  Bonne tablette pour le prix Fonctionne bien. M...
#
#                                                  text_cat  \
# 200999  Fonctionne bien. Mais autonomie très faible. C...
#
#         product_category_cod
# 200999                    21

# %% [markdown]
# # Carga modelo mBERT
# - incluye tokenizer

# %%
PRE_TRAINED_MODEL_NAME = 'bert-base-multilingual-cased'
from transformers import BertModel, BertConfig, BertTokenizer
from transformers import BertForSequenceClassification
tokenizer = BertTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)

# %% [markdown]
# # mBertForSequenceClassification - RATING
# - Clasificación Rating a partir de review_body

# %%
# %env WANDB_PROJECT = CLASSIFICATION mBERT fewshot
# Out:
# env: WANDB_PROJECT=CLASSIFICATION mBERT fewshot

# %%
# %env WANDB_WATCH = 'all'
# Out:
# env: WANDB_WATCH='all'

# %%
RANDOM_SEED=8
MAX_LENGTH=260


## CLASES DEL CLASIFICADOR 

class_names = ['0','1','2','3','4']

# %%
RANDOM_SEED=8
MAX_LENGTH=260


train_encodings = tokenizer(df_train.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_encodings = tokenizer(df_valid.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_encodings = tokenizer(df_test.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

# %%
class AMZReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_labels = df_train.star_rating.values
val_labels = df_valid.star_rating.values
test_labels = df_test.star_rating.values

# %%
train_data = AMZReviewDataset(train_encodings, torch.from_numpy(train_labels))
val_data = AMZReviewDataset(val_encodings, torch.from_numpy(val_labels))
test_data = AMZReviewDataset(test_encodings, torch.from_numpy(test_labels))

# %%
from transformers import BertForSequenceClassification

## DEFINIMOS EL MODELO 

model = BertForSequenceClassification.from_pretrained(
    PRE_TRAINED_MODEL_NAME,         # Use the 12-layer BERT model, with an uncased vocab.
    #'Chek4mv_multi',
    num_labels = len(class_names),  # The number of output labels--2 for binary classification.
    output_attentions = False,      # Whether the model returns attentions weights.
    output_hidden_states = False ,  # Whether the model returns all hidden-states.   
    vocab_size=tokenizer.vocab_size)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Training

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
#from datasets import load_metric
#import numpy as np

#accuracy_metric = load_metric("accuracy")

#def compute_metrics(eval_pred):
 #   predictions, labels = eval_pred
  #  predictions = np.argmax(predictions, axis=1)
    # metrics from the datasets library have a `compute` method
    #  return accuracy_metric.compute(predictions=predictions, references=labels)

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,                  # total number of training epochs
    per_device_train_batch_size=16,       # batch size per device during training
    per_device_eval_batch_size=64,       # batch size for evaluation
    warmup_steps=500,                    # number of warmup steps for learning rate scheduler
    weight_decay=0.01,                   # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',       # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',                # enable logging to W&B
    run_name = 'EN + DE - body'
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset
    eval_dataset = val_data,              # evaluation dataset
    compute_metrics=compute_metrics            
)

trainer.train()
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + DE - body</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/pdi23f3q" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/pdi23f3q</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210402_202153-pdi23f3q</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:46:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.970500</td>
#       <td>0.977799</td>
#       <td>0.571200</td>
#       <td>0.565802</td>
#       <td>0.575623</td>
#       <td>0.571200</td>
#       <td>44.251900</td>
#       <td>56.495000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.982700</td>
#       <td>0.959048</td>
#       <td>0.580800</td>
#       <td>0.573876</td>
#       <td>0.581993</td>
#       <td>0.580800</td>
#       <td>44.214200</td>
#       <td>56.543000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.843300</td>
#       <td>0.976048</td>
#       <td>0.586400</td>
#       <td>0.587556</td>
#       <td>0.590983</td>
#       <td>0.586400</td>
#       <td>44.193100</td>
#       <td>56.570000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=0.9268395415944405, metrics={'train_runtime': 35187.3182, 'train_samples_per_second': 0.536, 'total_flos': 1.673067908538e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 67058, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 40991760, 'train_mem_gpu_alloc_delta': 2884898304, 'train_mem_cpu_peaked_delta': 734440925, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
model_path = "Chek1mv_multi_fewshotDE"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_fewshotDE/tokenizer_config.json',
#  'Chek1mv_multi_fewshotDE/special_tokens_map.json',
#  'Chek1mv_multi_fewshotDE/vocab.txt',
#  'Chek1mv_multi_fewshotDE/added_tokens.json')

# %% [markdown]
# ## Evaluation sobre dato en idioma de entrenamiento (inglés)

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 01:27]
#     </div>
# wandb: WARNING Step must only increase in log calls.  Step 18846 < 18847; dropping {'eval/loss': 0.9590477347373962, 'eval/accuracy': 0.5808, 'eval/f1': 0.573876119731371, 'eval/precision': 0.5819928387103677, 'eval/recall': 0.5808, 'eval/runtime': 44.0778, 'eval/samples_per_second': 56.718, 'train/epoch': 3.0}.
# {'eval_loss': 0.9590477347373962,
#  'eval_accuracy': 0.5808,
#  'eval_f1': 0.573876119731371,
#  'eval_precision': 0.5819928387103677,
#  'eval_recall': 0.5808,
#  'eval_runtime': 44.0778,
#  'eval_samples_per_second': 56.718,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 180086,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 757606,
#  'eval_mem_gpu_peaked_delta': 773972480}

# %% [markdown]
# ## Test sobre dato en otros idiomas

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Aleman 
predictions,labels, metrics = trainer.predict(test_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Blues',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 
plt.title('few shot DE - body')

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.62      0.62       521
#            1       0.39      0.58      0.46       487
#            2       0.44      0.31      0.37       488
#            3       0.55      0.29      0.38       507
#            4       0.64      0.79      0.71       497
#
#     accuracy                           0.52      2500
#    macro avg       0.52      0.52      0.51      2500
# weighted avg       0.53      0.52      0.51      2500
#
# {'eval_loss': 1.1459470987319946, 'eval_accuracy': 0.5208, 'eval_f1': 0.507978907540312, 'eval_precision': 0.5261268696637448, 'eval_recall': 0.5208, 'eval_runtime': 44.3612, 'eval_samples_per_second': 56.356, 'test_mem_cpu_alloc_delta': 174997, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 762889, 'test_mem_gpu_peaked_delta': 773972480}

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,                  # total number of training epochs
    per_device_train_batch_size=16,       # batch size per device during training
    per_device_eval_batch_size=64,       # batch size for evaluation
    warmup_steps=500,                    # number of warmup steps for learning rate scheduler
    weight_decay=0.01,                   # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',       # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',                # enable logging to W&B
    run_name = 'EN + ES - body'
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset
    eval_dataset = val_data,              # evaluation dataset
    compute_metrics=compute_metrics            
)

trainer.train()
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + ES - body</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/rhm0zncf" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/rhm0zncf</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210403_104704-rhm0zncf</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:47:10, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.954500</td>
#       <td>0.986815</td>
#       <td>0.572800</td>
#       <td>0.567586</td>
#       <td>0.585376</td>
#       <td>0.572800</td>
#       <td>44.284500</td>
#       <td>56.453000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.998600</td>
#       <td>0.948398</td>
#       <td>0.585200</td>
#       <td>0.578219</td>
#       <td>0.583303</td>
#       <td>0.585200</td>
#       <td>43.873500</td>
#       <td>56.982000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.823700</td>
#       <td>0.970073</td>
#       <td>0.590400</td>
#       <td>0.591173</td>
#       <td>0.593774</td>
#       <td>0.590400</td>
#       <td>44.122900</td>
#       <td>56.660000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=0.91980027054369, metrics={'train_runtime': 35234.7983, 'train_samples_per_second': 0.535, 'total_flos': 1.673067908538e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 67058, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 40995684, 'train_mem_gpu_alloc_delta': 2884898304, 'train_mem_cpu_peaked_delta': 734425273, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
model_path = "Chek1mv_multi_fewshotES"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_fewshotES/tokenizer_config.json',
#  'Chek1mv_multi_fewshotES/special_tokens_map.json',
#  'Chek1mv_multi_fewshotES/vocab.txt',
#  'Chek1mv_multi_fewshotES/added_tokens.json')

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='60' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 17:35]
#     </div>
# wandb: WARNING Step must only increase in log calls.  Step 18846 < 18847; dropping {'eval/loss': 0.9483983516693115, 'eval/accuracy': 0.5852, 'eval/f1': 0.5782191325368669, 'eval/precision': 0.5833026849376637, 'eval/recall': 0.5852, 'eval/runtime': 43.5881, 'eval/samples_per_second': 57.355, 'train/epoch': 3.0}.
# {'eval_loss': 0.9483983516693115,
#  'eval_accuracy': 0.5852,
#  'eval_f1': 0.5782191325368669,
#  'eval_precision': 0.5833026849376637,
#  'eval_recall': 0.5852,
#  'eval_runtime': 43.5881,
#  'eval_samples_per_second': 57.355,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 176951,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 760121,
#  'eval_mem_gpu_peaked_delta': 773972480}

# %%
#Test Dato español  

path3 = "amazonES_valid.csv"
df_valid = pd.read_csv(path3)
df_valid = df_valid

val_encodings = tokenizer(df_valid.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_labels = df_valid.star_rating.values
val_data_ES =  AMZReviewDataset(val_encodings, torch.from_numpy(val_labels))

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report



## valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(val_data_ES)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Oranges',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.88      0.70       502
#            1       0.42      0.39      0.40       503
#            2       0.52      0.30      0.38       497
#            3       0.57      0.31      0.40       503
#            4       0.61      0.88      0.72       495
#
#     accuracy                           0.55      2500
#    macro avg       0.54      0.55      0.52      2500
# weighted avg       0.54      0.55      0.52      2500
#
# {'eval_loss': 0.9762808680534363, 'eval_accuracy': 0.5516, 'eval_f1': 0.5213355414045638, 'eval_precision': 0.5403221277150307, 'eval_recall': 0.5516, 'eval_runtime': 43.3994, 'eval_samples_per_second': 57.605, 'test_mem_cpu_alloc_delta': 175111, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 762369, 'test_mem_gpu_peaked_delta': 773972480}

# %%
## falta review_body en en+FR

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,                  # total number of training epochs
    per_device_train_batch_size=16,       # batch size per device during training
    per_device_eval_batch_size=64,       # batch size for evaluation
    warmup_steps=500,                    # number of warmup steps for learning rate scheduler
    weight_decay=0.01,                   # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',       # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',                # enable logging to W&B
    run_name = 'EN + FR - body'
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset
    eval_dataset = val_data,              # evaluation dataset
    compute_metrics=compute_metrics            
)

trainer.train()
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + FR - body</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1le48272" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1le48272</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210403_232228-1le48272</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:48:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.967900</td>
#       <td>0.988238</td>
#       <td>0.571600</td>
#       <td>0.568567</td>
#       <td>0.579666</td>
#       <td>0.571600</td>
#       <td>44.000700</td>
#       <td>56.817000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.983800</td>
#       <td>0.955318</td>
#       <td>0.586800</td>
#       <td>0.579909</td>
#       <td>0.586015</td>
#       <td>0.586800</td>
#       <td>44.117600</td>
#       <td>56.667000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.834500</td>
#       <td>0.973407</td>
#       <td>0.584800</td>
#       <td>0.584349</td>
#       <td>0.586148</td>
#       <td>0.584800</td>
#       <td>44.278700</td>
#       <td>56.461000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=0.9269864434941893, metrics={'train_runtime': 35303.2741, 'train_samples_per_second': 0.534, 'total_flos': 1.673067908538e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 67058, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 40996502, 'train_mem_gpu_alloc_delta': 2884898304, 'train_mem_cpu_peaked_delta': 734427000, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 01:28]
#     </div>
# wandb: WARNING Step must only increase in log calls.  Step 18846 < 18847; dropping {'eval/loss': 0.9553177952766418, 'eval/accuracy': 0.5868, 'eval/f1': 0.5799091867535469, 'eval/precision': 0.5860145450558535, 'eval/recall': 0.5868, 'eval/runtime': 43.7085, 'eval/samples_per_second': 57.197, 'train/epoch': 3.0}.
# {'eval_loss': 0.9553177952766418,
#  'eval_accuracy': 0.5868,
#  'eval_f1': 0.5799091867535469,
#  'eval_precision': 0.5860145450558535,
#  'eval_recall': 0.5868,
#  'eval_runtime': 43.7085,
#  'eval_samples_per_second': 57.197,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 175240,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 756378,
#  'eval_mem_gpu_peaked_delta': 773972480}

# %%
model_path = "Chek1mv_multi_fewshotFR"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_fewshotFR/tokenizer_config.json',
#  'Chek1mv_multi_fewshotFR/special_tokens_map.json',
#  'Chek1mv_multi_fewshotFR/vocab.txt',
#  'Chek1mv_multi_fewshotFR/added_tokens.json')

# %%
#Test Dato frances  

path3 = "amazonFR_valid.csv"
df_valid = pd.read_csv(path3)
df_valid = df_valid

val_encodings = tokenizer(df_valid.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_labels = df_valid.star_rating.values
val_data_FR = AMZReviewDataset(val_encodings, torch.from_numpy(val_labels))

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

## valid data en FRANCES
predictions,labels, metrics = trainer.predict(val_data_FR)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Greens',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.79      0.71       503
#            1       0.49      0.58      0.53       490
#            2       0.51      0.38      0.44       493
#            3       0.59      0.39      0.47       512
#            4       0.64      0.78      0.70       502
#
#     accuracy                           0.58      2500
#    macro avg       0.58      0.58      0.57      2500
# weighted avg       0.58      0.58      0.57      2500
#
# {'eval_loss': 0.9685613512992859, 'eval_accuracy': 0.5836, 'eval_f1': 0.5716987245012258, 'eval_precision': 0.5778224802994872, 'eval_recall': 0.5836, 'eval_runtime': 44.0563, 'eval_samples_per_second': 56.746, 'test_mem_cpu_alloc_delta': 175184, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 761914, 'test_mem_gpu_peaked_delta': 773972480}

# %% [markdown]
# ## Save Model final

# %%
# !ls drive/MyDrive/TFG_1/Modelos_entrenados/

# %%
# saving the fine tuned model & tokenizer
model_path = "Rating_text_mBERT_final"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %% [markdown]
# # mBertForSequenceClassification - RATING
# - Clasificación Rating a partir de review_body + titulo

# %%
RANDOM_SEED=8
MAX_LENGTH=260


## CLASES DEL CLASIFICADOR 

class_names = ['0','1','2','3','4']

# %%
#TOKENIZAMOS LOS DATAFRAMES

train_encodings = tokenizer(df_train.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_encodings = tokenizer(df_valid.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

# %%
class GPReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_labels = df_train.star_rating.values
val_labels = df_valid.star_rating.values
test_labels = df_test.star_rating.values

# %%
train_data = GPReviewDataset(train_encodings, torch.from_numpy(train_labels))
val_data = GPReviewDataset(val_encodings, torch.from_numpy(val_labels))
test_data = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

# %%
## Lo definimos de nuevo unicamente con el proposito de usar las secciones del documento de forma independiente 

model = BertForSequenceClassification.from_pretrained(
    PRE_TRAINED_MODEL_NAME, # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = len(class_names), # The number of output labels--2 for binary classification.  si pones num_labels=1 hace MSE LOSS
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False ,# Whether the model returns all hidden-states.   
    vocab_size=tokenizer.vocab_size)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %% [markdown]
# ## Training

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN-DE - Rating_body_title'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset en inles
    eval_dataset = val_data,               # evaluation dataset en ingles
    compute_metrics=compute_metrics                   
)

trainer.train()
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN-DE - Rating_body_title</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1ou9jp9b" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1ou9jp9b</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210404_142002-1ou9jp9b</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:48:04, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.828700</td>
#       <td>0.848755</td>
#       <td>0.640400</td>
#       <td>0.638686</td>
#       <td>0.644350</td>
#       <td>0.640400</td>
#       <td>44.268300</td>
#       <td>56.474000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.877800</td>
#       <td>0.857120</td>
#       <td>0.645600</td>
#       <td>0.640659</td>
#       <td>0.647557</td>
#       <td>0.645600</td>
#       <td>43.910500</td>
#       <td>56.934000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.638600</td>
#       <td>0.856768</td>
#       <td>0.649200</td>
#       <td>0.648529</td>
#       <td>0.649317</td>
#       <td>0.649200</td>
#       <td>44.008600</td>
#       <td>56.807000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=0.7903401030611615, metrics={'train_runtime': 35288.5855, 'train_samples_per_second': 0.534, 'total_flos': 1.673067908538e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 67058, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 40998992, 'train_mem_gpu_alloc_delta': 2884898304, 'train_mem_cpu_peaked_delta': 734425367, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
model_path = "Chek1mv_multi_2_fewshotDE"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_2_fewshotDE/tokenizer_config.json',
#  'Chek1mv_multi_2_fewshotDE/special_tokens_map.json',
#  'Chek1mv_multi_2_fewshotDE/vocab.txt',
#  'Chek1mv_multi_2_fewshotDE/added_tokens.json')

# %% [markdown]
# ## Evaluation en ingles

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 01:26]
#     </div>
# wandb: WARNING Step must only increase in log calls.  Step 18846 < 18847; dropping {'eval/loss': 0.8487550616264343, 'eval/accuracy': 0.6404, 'eval/f1': 0.6386859790745187, 'eval/precision': 0.644349739248146, 'eval/recall': 0.6404, 'eval/runtime': 43.6721, 'eval/samples_per_second': 57.245, 'train/epoch': 3.0}.
# {'eval_loss': 0.8487550616264343,
#  'eval_accuracy': 0.6404,
#  'eval_f1': 0.6386859790745187,
#  'eval_precision': 0.644349739248146,
#  'eval_recall': 0.6404,
#  'eval_runtime': 43.6721,
#  'eval_samples_per_second': 57.245,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 182158,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 755073,
#  'eval_mem_gpu_peaked_delta': 773972480}

# %% [markdown]
# ## Test en otros idiomas

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Aleman 
predictions,labels, metrics = trainer.predict(test_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Blues',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.72      0.67       521
#            1       0.46      0.47      0.47       487
#            2       0.50      0.43      0.46       488
#            3       0.54      0.33      0.41       507
#            4       0.61      0.83      0.71       497
#
#     accuracy                           0.56      2500
#    macro avg       0.55      0.56      0.54      2500
# weighted avg       0.55      0.56      0.54      2500
#
# {'eval_loss': 1.0339486598968506, 'eval_accuracy': 0.5576, 'eval_f1': 0.5434609384209383, 'eval_precision': 0.548756614903243, 'eval_recall': 0.5576, 'eval_runtime': 44.0342, 'eval_samples_per_second': 56.774, 'test_mem_cpu_alloc_delta': 170449, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 764044, 'test_mem_gpu_peaked_delta': 773972480}

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + ES - Rating_body_title'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset en inles
    eval_dataset = val_data,               # evaluation dataset en ingles
    compute_metrics=compute_metrics                   
)

trainer.train()
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + ES - Rating_body_title</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1xhavepz" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1xhavepz</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210405_082214-1xhavepz</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:48:48, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.810800</td>
#       <td>0.851568</td>
#       <td>0.645200</td>
#       <td>0.643558</td>
#       <td>0.652367</td>
#       <td>0.645200</td>
#       <td>44.208200</td>
#       <td>56.551000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.854200</td>
#       <td>0.858062</td>
#       <td>0.637600</td>
#       <td>0.630961</td>
#       <td>0.641403</td>
#       <td>0.637600</td>
#       <td>43.980800</td>
#       <td>56.843000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.653100</td>
#       <td>0.861564</td>
#       <td>0.648400</td>
#       <td>0.648783</td>
#       <td>0.650373</td>
#       <td>0.648400</td>
#       <td>44.284400</td>
#       <td>56.453000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=0.7862129451539579, metrics={'train_runtime': 35332.3234, 'train_samples_per_second': 0.533, 'total_flos': 1.673067908538e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 67058, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 40996136, 'train_mem_gpu_alloc_delta': 2884898304, 'train_mem_cpu_peaked_delta': 734425127, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
model_path = "Chek1mv_multi_2_fewshotES"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_2_fewshotES/tokenizer_config.json',
#  'Chek1mv_multi_2_fewshotES/special_tokens_map.json',
#  'Chek1mv_multi_2_fewshotES/vocab.txt',
#  'Chek1mv_multi_2_fewshotES/added_tokens.json')

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='60' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 16:55]
#     </div>
# wandb: WARNING Step must only increase in log calls.  Step 18846 < 18847; dropping {'eval/loss': 0.8515676856040955, 'eval/accuracy': 0.6452, 'eval/f1': 0.6435582557688454, 'eval/precision': 0.6523666374190807, 'eval/recall': 0.6452, 'eval/runtime': 43.579, 'eval/samples_per_second': 57.367, 'train/epoch': 3.0}.
# {'eval_loss': 0.8515676856040955,
#  'eval_accuracy': 0.6452,
#  'eval_f1': 0.6435582557688454,
#  'eval_precision': 0.6523666374190807,
#  'eval_recall': 0.6452,
#  'eval_runtime': 43.579,
#  'eval_samples_per_second': 57.367,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 180528,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 756331,
#  'eval_mem_gpu_peaked_delta': 773972480}

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report


#Test Dato español  

path3 = "amazonES_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.star_rating.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_ES)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Oranges',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64       498
#            1       0.46      0.55      0.50       497
#            2       0.48      0.37      0.42       503
#            3       0.47      0.24      0.32       497
#            4       0.53      0.82      0.65       505
#
#     accuracy                           0.52      2500
#    macro avg       0.52      0.52      0.50      2500
# weighted avg       0.52      0.52      0.51      2500
#
# {'eval_loss': 1.107100009918213, 'eval_accuracy': 0.524, 'eval_f1': 0.5051164367951874, 'eval_precision': 0.5184169646837045, 'eval_recall': 0.524, 'eval_runtime': 43.3962, 'eval_samples_per_second': 57.609, 'test_mem_cpu_alloc_delta': 169801, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 765750, 'test_mem_gpu_peaked_delta': 773972480}

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + FR - Rating_body_title'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset en inles
    eval_dataset = val_data,               # evaluation dataset en ingles
    compute_metrics=compute_metrics                   
)

trainer.train()
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + FR - Rating_body_title</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/16hcg6jv" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/16hcg6jv</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210405_210246-16hcg6jv</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:48:50, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.804800</td>
#       <td>0.842536</td>
#       <td>0.639200</td>
#       <td>0.635708</td>
#       <td>0.640186</td>
#       <td>0.639200</td>
#       <td>43.799800</td>
#       <td>57.078000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.866500</td>
#       <td>0.842074</td>
#       <td>0.651200</td>
#       <td>0.647188</td>
#       <td>0.654617</td>
#       <td>0.651200</td>
#       <td>43.818100</td>
#       <td>57.054000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.629400</td>
#       <td>0.858249</td>
#       <td>0.646800</td>
#       <td>0.646557</td>
#       <td>0.647761</td>
#       <td>0.646800</td>
#       <td>44.220500</td>
#       <td>56.535000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=0.7868641469302254, metrics={'train_runtime': 35335.1611, 'train_samples_per_second': 0.533, 'total_flos': 1.673067908538e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 67058, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 40990725, 'train_mem_gpu_alloc_delta': 2884898304, 'train_mem_cpu_peaked_delta': 734425722, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
#Test Dato frances  
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

path3 = "amazonFR_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.star_rating.values
test_data_FR = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_FR)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Greens',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.67       497
#            1       0.46      0.57      0.51       510
#            2       0.47      0.38      0.42       507
#            3       0.46      0.38      0.42       488
#            4       0.62      0.66      0.64       498
#
#     accuracy                           0.54      2500
#    macro avg       0.53      0.54      0.53      2500
# weighted avg       0.53      0.54      0.53      2500
#
# {'eval_loss': 1.053649663925171, 'eval_accuracy': 0.5356, 'eval_f1': 0.5305871056668774, 'eval_precision': 0.5319753007762059, 'eval_recall': 0.5356, 'eval_runtime': 43.4763, 'eval_samples_per_second': 57.503, 'test_mem_cpu_alloc_delta': 167865, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 768128, 'test_mem_gpu_peaked_delta': 773972480}

# %%
#Test Dato inglés (idioma de entrenamiento) 

path3 = "amazonEN_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.star_rating.values
test_data_EN = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ingles
predictions,labels, metrics = trainer.predict(test_data_EN)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Purples',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.80      0.71       480
#            1       0.55      0.61      0.58       530
#            2       0.59      0.43      0.50       501
#            3       0.63      0.53      0.58       479
#            4       0.75      0.81      0.78       510
#
#     accuracy                           0.64      2500
#    macro avg       0.63      0.64      0.63      2500
# weighted avg       0.63      0.64      0.63      2500
#
# {'eval_loss': 0.8185927867889404, 'eval_accuracy': 0.6356, 'eval_f1': 0.6289074161103984, 'eval_precision': 0.6331214327223149, 'eval_recall': 0.6356, 'eval_runtime': 43.3974, 'eval_samples_per_second': 57.607, 'test_mem_cpu_alloc_delta': 172545, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 768951, 'test_mem_gpu_peaked_delta': 773972480}

# %% [markdown]
# ## Save Model

# %%
model_path = "Chek1mv_multi_2_fewshotFR"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_2_fewshotFR/tokenizer_config.json',
#  'Chek1mv_multi_2_fewshotFR/special_tokens_map.json',
#  'Chek1mv_multi_2_fewshotFR/vocab.txt',
#  'Chek1mv_multi_2_fewshotFR/added_tokens.json')

# %% [markdown]
# # mBertForSequenceClassification - RATING
# - Clasificación Rating a partir de review_body + titulo + categoria

# %%
RANDOM_SEED=8
MAX_LENGTH=260


## CLASES DEL CLASIFICADOR 

class_names = ['0','1','2','3','4'] 
#class_names = ['0','1'] 
#class_names = ['1']

# %%
#TOKENIZAMOS LOS DATAFRAMES

train_encodings = tokenizer(df_train.text_title_cat.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_encodings = tokenizer(df_valid.text_title_cat.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_encodings = tokenizer(df_test.text_title_cat.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

# %%
class GPReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_labels = df_train.star_rating.values
val_labels = df_valid.star_rating.values
test_labels = df_test.star_rating.values

# %%
train_data = GPReviewDataset(train_encodings, torch.from_numpy(train_labels))
val_data = GPReviewDataset(val_encodings, torch.from_numpy(val_labels))
test_data = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

# %%
model = BertForSequenceClassification.from_pretrained(
    PRE_TRAINED_MODEL_NAME, # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = len(class_names), # The number of output labels--2 for binary classification.  si pones num_labels=1 hace MSE LOSS
    output_attentions = False, # Whether the model returns attentions weights. --> importante para la visualización de los pesos de atención
    output_hidden_states = False ,# Whether the model returns all hidden-states.   
    vocab_size=tokenizer.vocab_size)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %% [markdown]
# ## Training

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + DE - Rating_body_title_cat'   # name of the W&B run

)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset
    eval_dataset = val_data,             # evaluation dataset
    compute_metrics=compute_metrics             
)

trainer.train()
# Out:
# wandb: wandb version 0.10.26 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + DE - Rating_body_title_cat</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/2cne0s7h" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/2cne0s7h</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210414_101359-2cne0s7h</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:52:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.835900</td>
#       <td>0.847284</td>
#       <td>0.644800</td>
#       <td>0.642302</td>
#       <td>0.649602</td>
#       <td>0.644800</td>
#       <td>44.752700</td>
#       <td>55.863000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.898200</td>
#       <td>0.846045</td>
#       <td>0.637600</td>
#       <td>0.633571</td>
#       <td>0.644482</td>
#       <td>0.637600</td>
#       <td>44.724400</td>
#       <td>55.898000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.642400</td>
#       <td>0.862009</td>
#       <td>0.646000</td>
#       <td>0.646084</td>
#       <td>0.647254</td>
#       <td>0.646000</td>
#       <td>44.715600</td>
#       <td>55.909000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=0.792427448549304, metrics={'train_runtime': 35544.9038, 'train_samples_per_second': 0.53, 'total_flos': 1.673067908538e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 4096, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 0, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 983220224, 'train_mem_gpu_alloc_delta': 2884898304, 'train_mem_cpu_peaked_delta': 871292928, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
model_path = "Chek1mv_multi_3_fewshotDE"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_3_fewshotDE/tokenizer_config.json',
#  'Chek1mv_multi_3_fewshotDE/special_tokens_map.json',
#  'Chek1mv_multi_3_fewshotDE/vocab.txt',
#  'Chek1mv_multi_3_fewshotDE/added_tokens.json')

# %% [markdown]
# ## Evaluation en inglés

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 01:28]
#     </div>
# {'eval_loss': 0.8460451364517212,
#  'eval_accuracy': 0.6376,
#  'eval_f1': 0.633570502760466,
#  'eval_precision': 0.6444815927372494,
#  'eval_recall': 0.6376,
#  'eval_runtime': 44.3661,
#  'eval_samples_per_second': 56.349,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 0,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 0,
#  'eval_mem_gpu_peaked_delta': 773972480}

# %% [markdown]
# ## Test en otros idiomas

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Aleman 
predictions,labels, metrics = trainer.predict(test_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Blues',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.57      0.64       521
#            1       0.43      0.67      0.52       487
#            2       0.49      0.37      0.42       488
#            3       0.57      0.39      0.47       507
#            4       0.67      0.80      0.73       497
#
#     accuracy                           0.56      2500
#    macro avg       0.58      0.56      0.56      2500
# weighted avg       0.58      0.56      0.56      2500
#
# {'test_loss': 1.0152345895767212, 'test_accuracy': 0.5628, 'test_f1': 0.5571869362039498, 'test_precision': 0.5778836207135041, 'test_recall': 0.5628, 'test_runtime': 44.5659, 'test_samples_per_second': 56.097, 'test_mem_cpu_alloc_delta': 1003520, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 0, 'test_mem_gpu_peaked_delta': 773972480}

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + ES - Rating_body_title_cat'   # name of the W&B run

)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset
    eval_dataset = val_data,             # evaluation dataset
    compute_metrics=compute_metrics             
)

trainer.train()
# Out:
# wandb: wandb version 0.10.26 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + ES - Rating_body_title_cat</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1giq3pkm" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1giq3pkm</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210414_205616-1giq3pkm</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:52:24, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.843400</td>
#       <td>0.848112</td>
#       <td>0.635600</td>
#       <td>0.635488</td>
#       <td>0.644964</td>
#       <td>0.635600</td>
#       <td>44.636200</td>
#       <td>56.008000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.886400</td>
#       <td>0.854727</td>
#       <td>0.640800</td>
#       <td>0.636459</td>
#       <td>0.645741</td>
#       <td>0.640800</td>
#       <td>44.655000</td>
#       <td>55.985000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.659300</td>
#       <td>0.867853</td>
#       <td>0.656000</td>
#       <td>0.655690</td>
#       <td>0.656624</td>
#       <td>0.656000</td>
#       <td>44.662600</td>
#       <td>55.975000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=0.7911670122204294, metrics={'train_runtime': 35549.1565, 'train_samples_per_second': 0.53, 'total_flos': 1.673067908538e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 4096, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 0, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 356605952, 'train_mem_gpu_alloc_delta': 2884898304, 'train_mem_cpu_peaked_delta': 1081131008, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
model_path = "Chek1mv_multi_3_fewshotES"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_3_fewshotES/tokenizer_config.json',
#  'Chek1mv_multi_3_fewshotES/special_tokens_map.json',
#  'Chek1mv_multi_3_fewshotES/vocab.txt',
#  'Chek1mv_multi_3_fewshotES/added_tokens.json')

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='60' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 2:50:16]
#     </div>
# {'eval_loss': 0.8481119275093079,
#  'eval_accuracy': 0.6356,
#  'eval_f1': 0.6354879220121398,
#  'eval_precision': 0.6449639603493941,
#  'eval_recall': 0.6356,
#  'eval_runtime': 44.3642,
#  'eval_samples_per_second': 56.352,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 0,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 0,
#  'eval_mem_gpu_peaked_delta': 773972480}

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report


#Test Dato español  

path3 = "amazonES_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.star_rating.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_ES)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Oranges',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.68      0.64       498
#            1       0.44      0.54      0.49       497
#            2       0.44      0.37      0.40       503
#            3       0.51      0.25      0.33       497
#            4       0.57      0.76      0.66       505
#
#     accuracy                           0.52      2500
#    macro avg       0.51      0.52      0.50      2500
# weighted avg       0.51      0.52      0.50      2500
#
# {'test_loss': 1.0924179553985596, 'test_accuracy': 0.52, 'test_f1': 0.5030994770861096, 'test_precision': 0.5135617019438614, 'test_recall': 0.52, 'test_runtime': 44.151, 'test_samples_per_second': 56.624, 'test_mem_cpu_alloc_delta': 0, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 0, 'test_mem_gpu_peaked_delta': 773972480}

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + FR - Rating_body_title_cat'   # name of the W&B run

)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset
    eval_dataset = val_data,             # evaluation dataset
    compute_metrics=compute_metrics             
)

trainer.train()
# Out:
# wandb: wandb version 0.10.26 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + FR - Rating_body_title_cat</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/bn5w6w4j" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/bn5w6w4j</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210415_095300-bn5w6w4j</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:51:21, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.812000</td>
#       <td>0.841775</td>
#       <td>0.644800</td>
#       <td>0.644260</td>
#       <td>0.650707</td>
#       <td>0.644800</td>
#       <td>44.781400</td>
#       <td>55.827000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.895400</td>
#       <td>0.851749</td>
#       <td>0.642000</td>
#       <td>0.639270</td>
#       <td>0.647972</td>
#       <td>0.642000</td>
#       <td>44.778900</td>
#       <td>55.830000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.638800</td>
#       <td>0.848977</td>
#       <td>0.650400</td>
#       <td>0.650881</td>
#       <td>0.653302</td>
#       <td>0.650400</td>
#       <td>44.827500</td>
#       <td>55.769000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=0.7919578845999644, metrics={'train_runtime': 35486.1839, 'train_samples_per_second': 0.531, 'total_flos': 1.673067908538e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 4096, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 0, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 962367488, 'train_mem_gpu_alloc_delta': 2884898304, 'train_mem_cpu_peaked_delta': 887672832, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 01:39]
#     </div>
# {'eval_loss': 0.841775119304657,
#  'eval_accuracy': 0.6448,
#  'eval_f1': 0.6442599924763887,
#  'eval_precision': 0.6507070151955788,
#  'eval_recall': 0.6448,
#  'eval_runtime': 44.5409,
#  'eval_samples_per_second': 56.128,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 24576,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 36864,
#  'eval_mem_gpu_peaked_delta': 773972480}

# %%
model_path = "Chek1mv_multi_3_fewshotFR"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_3_fewshotFR/tokenizer_config.json',
#  'Chek1mv_multi_3_fewshotFR/special_tokens_map.json',
#  'Chek1mv_multi_3_fewshotFR/vocab.txt',
#  'Chek1mv_multi_3_fewshotFR/added_tokens.json')

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

#Test Dato frances  

path3 = "amazonFR_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.star_rating.values
test_data_FR = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_FR)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Greens',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.75      0.65       497
#            1       0.47      0.49      0.48       510
#            2       0.51      0.43      0.47       507
#            3       0.52      0.27      0.35       488
#            4       0.60      0.79      0.68       498
#
#     accuracy                           0.54      2500
#    macro avg       0.54      0.54      0.53      2500
# weighted avg       0.54      0.54      0.53      2500
#
# {'test_loss': 1.0786819458007812, 'test_accuracy': 0.5436, 'test_f1': 0.5260998758466235, 'test_precision': 0.5351796421286202, 'test_recall': 0.5436, 'test_runtime': 44.6456, 'test_samples_per_second': 55.997, 'test_mem_cpu_alloc_delta': 0, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 0, 'test_mem_gpu_peaked_delta': 773972480}

# %% [markdown]
# ## Visualización de la atención con BertViz

# %%
# !pip install bertviz

# %%
inputs = tokenizer.encode("I like this product so much", return_tensors='pt')
outputs = model(inputs)
attention = outputs[-1]                      # Output includes attention weights when output_attentions=True
tokens = tokenizer.convert_ids_to_tokens(inputs[0])

# %% [markdown]
# ## Save Model

# %%
# !ls drive/MyDrive/TFG_1/Modelos_entrenados/

# %%
# saving the fine tuned model & tokenizer
model_path = "drive/MyDrive/TFG_1/Modelos_entrenados/Rating_text_title_cat_mBERT"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %% [markdown]
# # BertForSequenceClassification - CATEGORÍA
#
# - Clasificación de categorias de productos a partir del review_body

# %%
RANDOM_SEED=8
MAX_LENGTH=260


## CLASES DEL CLASIFICADOR 

class_names = df_train.product_category.unique().tolist()

# %%
#TOKENIZAMOS LOS DATAFRAMES

train_encodings = tokenizer(df_train.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_encodings = tokenizer(df_valid.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_encodings = tokenizer(df_test.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

# %%
class GPReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_labels = df_train.product_category_cod.values
val_labels = df_valid.product_category_cod.values
test_labels = df_test.product_category_cod.values

# %%
train_data = GPReviewDataset(train_encodings, torch.from_numpy(train_labels))
val_data = GPReviewDataset(val_encodings, torch.from_numpy(val_labels))
test_data = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

# %%
model = BertForSequenceClassification.from_pretrained(
    'Chek1mv_multi_fewshotES_4', # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = len(class_names), # The number of output labels--2 for binary classification.  si pones num_labels=1 hace MSE LOSS
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False ,# Whether the model returns all hidden-states.   
    vocab_size=tokenizer.vocab_size)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %% [markdown]
# ## Training

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + DE - body- category'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,            # evaluation dataset
    compute_metrics = compute_metrics             
)

trainer.train()
# Out:
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + DE - body- category</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1amd1q5s" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1amd1q5s</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210409_091237-1amd1q5s</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='17563' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [17563/18846 8:35:12 < 37:38, 0.57 it/s, Epoch 2.80/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.953500</td>
#       <td>1.796255</td>
#       <td>0.488400</td>
#       <td>0.475184</td>
#       <td>0.492191</td>
#       <td>0.488400</td>
#       <td>42.992200</td>
#       <td>58.150000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.504100</td>
#       <td>1.691387</td>
#       <td>0.519200</td>
#       <td>0.506029</td>
#       <td>0.525029</td>
#       <td>0.519200</td>
#       <td>43.404900</td>
#       <td>57.597000</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
from transformers import Trainer, TrainingArguments

model_dir="./"

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + DE - body- category'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,            # evaluation dataset
    compute_metrics = compute_metrics             
)

# %%
model_path = "Chek1mv_multi_fewshotDE_4"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %% [markdown]
# ## Evaluation

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 01:58]
#     </div>
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + DE - body- category</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/2dgyrooo" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/2dgyrooo</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210409_224709-2dgyrooo</code><br/><br/>
# {'eval_loss': 1.6624119281768799,
#  'eval_accuracy': 0.5384,
#  'eval_f1': 0.5282885703635256,
#  'eval_precision': 0.5297847591598548,
#  'eval_recall': 0.5384,
#  'eval_runtime': 42.8702,
#  'eval_samples_per_second': 58.316,
#  'init_mem_cpu_alloc_delta': 4096,
#  'init_mem_gpu_alloc_delta': 0,
#  'init_mem_cpu_peaked_delta': 0,
#  'init_mem_gpu_peaked_delta': 0,
#  'eval_mem_cpu_alloc_delta': 373936128,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 1757184,
#  'eval_mem_gpu_peaked_delta': 774225408}

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Aleman 


predictions,labels, metrics = trainer.predict(test_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Blues',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.39      0.42       114
#            1       0.27      0.16      0.20        62
#            2       0.29      0.19      0.22        54
#            3       0.50      0.50      0.50       111
#            4       0.70      0.58      0.63        55
#            5       0.24      0.25      0.24        16
#            6       0.50      0.48      0.49        27
#            7       0.70      0.72      0.71        39
#            8       0.18      0.20      0.19        96
#            9       0.37      0.16      0.22       103
#           10       0.22      0.18      0.20        78
#           11       0.33      0.27      0.30        30
#           12       0.31      0.40      0.35       338
#           13       0.23      0.20      0.21       163
#           14       0.00      0.00      0.00        13
#           15       0.40      0.64      0.49        33
#           16       0.19      0.16      0.17        74
#           17       0.33      0.26      0.29        98
#           18       0.22      0.10      0.14        41
#           19       0.25      0.17      0.20        12
#           20       0.31      0.29      0.30        51
#           21       0.13      0.18      0.15        68
#           22       0.38      0.31      0.34       106
#           23       0.00      0.00      0.00        35
#           24       0.40      0.44      0.42        70
#           25       0.49      0.53      0.51        47
#           26       0.24      0.28      0.26       154
#           27       0.31      0.32      0.32       120
#           28       0.70      0.44      0.54        16
#           29       0.52      0.47      0.49        30
#           30       0.38      0.57      0.45       246
#
#     accuracy                           0.34      2500
#    macro avg       0.34      0.32      0.32      2500
# weighted avg       0.33      0.34      0.33      2500
#
# {'test_loss': 2.525547504425049, 'test_accuracy': 0.3376, 'test_f1': 0.32789278682446454, 'test_precision': 0.332220000722332, 'test_recall': 0.3376, 'test_runtime': 41.641, 'test_samples_per_second': 60.037, 'test_mem_cpu_alloc_delta': 5017600, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 0, 'test_mem_gpu_peaked_delta': 774225408}

# %%
from transformers import Trainer, TrainingArguments

model_dir="./"

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + ES - body- category'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,            # evaluation dataset
    compute_metrics = compute_metrics             
)
trainer.train()
# Out:
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + ES - body- category</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/a7rudwp4" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/a7rudwp4</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210409_230111-a7rudwp4</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='1335' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 1335/18846 38:13 < 8:22:03, 0.58 it/s, Epoch 0.21/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
model_path = "Chek1mv_multi_fewshotES_4"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %%
from transformers import Trainer, TrainingArguments

model_dir="./"

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + ES - body- category'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,            # evaluation dataset
    compute_metrics = compute_metrics             
)

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 02:31]
#     </div>
# {'eval_loss': 1.6644030809402466,
#  'eval_accuracy': 0.5296,
#  'eval_f1': 0.5186100416285275,
#  'eval_precision': 0.5191661466870623,
#  'eval_recall': 0.5296,
#  'eval_runtime': 44.0457,
#  'eval_samples_per_second': 56.759,
#  'init_mem_cpu_alloc_delta': 4096,
#  'init_mem_gpu_alloc_delta': 0,
#  'init_mem_cpu_peaked_delta': 0,
#  'init_mem_gpu_peaked_delta': 0,
#  'eval_mem_cpu_alloc_delta': -65536,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 184320,
#  'eval_mem_gpu_peaked_delta': 774225408}

# %%
#Test Dato español  

path3 = "amazonES_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_ES)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Oranges',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.34      0.19      0.24        75
#            1       0.47      0.17      0.25        93
#            2       0.60      0.06      0.11        49
#            3       0.24      0.31      0.27        78
#            4       0.54      0.61      0.57        61
#            5       0.29      0.05      0.08        44
#            6       0.67      0.57      0.62        21
#            7       0.00      0.00      0.00        59
#            8       0.26      0.11      0.15       136
#            9       0.00      0.00      0.00        57
#           10       0.00      0.00      0.00        16
#           11       0.20      0.56      0.29       354
#           12       0.15      0.07      0.09       146
#           13       0.00      0.00      0.00        21
#           14       0.00      0.00      0.00        30
#           15       0.00      0.00      0.00        87
#           16       0.00      0.00      0.00        52
#           17       0.00      0.00      0.00        44
#           18       0.00      0.00      0.00        15
#           19       0.00      0.00      0.00        58
#           20       0.00      0.00      0.00        40
#           21       0.20      0.08      0.11       151
#           22       0.00      0.00      0.00        37
#           23       0.00      0.00      0.00        52
#           24       0.11      0.07      0.09        28
#           25       0.15      0.09      0.11       185
#           26       0.25      0.17      0.21       166
#           27       0.13      0.09      0.11        22
#           28       0.00      0.00      0.00        19
#           29       0.28      0.63      0.39       304
#           30       0.00      0.00      0.00         0
#
#     accuracy                           0.23      2500
#    macro avg       0.16      0.12      0.12      2500
# weighted avg       0.20      0.23      0.18      2500
#
# {'test_loss': 2.901413679122925, 'test_accuracy': 0.2344, 'test_f1': 0.18096032583252347, 'test_precision': 0.19841192121614312, 'test_recall': 0.2344, 'test_runtime': 44.2865, 'test_samples_per_second': 56.451, 'test_mem_cpu_alloc_delta': 348160, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 0, 'test_mem_gpu_peaked_delta': 774225408}

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + FR - body- category'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,            # evaluation dataset
    compute_metrics = compute_metrics             
)

trainer.train()
# Out:
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + FR - body- category</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/2xu3j4r4" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/2xu3j4r4</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210410_104053-2xu3j4r4</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:09:11, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.922100</td>
#       <td>1.800417</td>
#       <td>0.491600</td>
#       <td>0.481242</td>
#       <td>0.504775</td>
#       <td>0.491600</td>
#       <td>43.004500</td>
#       <td>58.133000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.530700</td>
#       <td>1.696129</td>
#       <td>0.516000</td>
#       <td>0.503621</td>
#       <td>0.526104</td>
#       <td>0.516000</td>
#       <td>42.688300</td>
#       <td>58.564000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.496000</td>
#       <td>1.672628</td>
#       <td>0.528000</td>
#       <td>0.517834</td>
#       <td>0.519182</td>
#       <td>0.528000</td>
#       <td>43.091900</td>
#       <td>58.016000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=1.718425969440922, metrics={'train_runtime': 32955.894, 'train_samples_per_second': 0.572, 'total_flos': 1.6732559880972e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 0, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 0, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 889327616, 'train_mem_gpu_alloc_delta': 2885137920, 'train_mem_cpu_peaked_delta': 847777792, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + FR - body- category'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,            # evaluation dataset
    compute_metrics = compute_metrics             
)

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 03:44]
#     </div>
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + FR - body- category</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1scxdzw0" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/1scxdzw0</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210412_134808-1scxdzw0</code><br/><br/>
# {'eval_loss': 1.6726279258728027,
#  'eval_accuracy': 0.528,
#  'eval_f1': 0.5178335831959855,
#  'eval_precision': 0.5191816719158956,
#  'eval_recall': 0.528,
#  'eval_runtime': 45.0,
#  'eval_samples_per_second': 55.556,
#  'init_mem_cpu_alloc_delta': 4096,
#  'init_mem_gpu_alloc_delta': 0,
#  'init_mem_cpu_peaked_delta': 0,
#  'init_mem_gpu_peaked_delta': 0,
#  'eval_mem_cpu_alloc_delta': 387076096,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 0,
#  'eval_mem_gpu_peaked_delta': 774225408}

# %%
model_path = "Chek1mv_multi_fewshotFR_4"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_fewshotFR_4/tokenizer_config.json',
#  'Chek1mv_multi_fewshotFR_4/special_tokens_map.json',
#  'Chek1mv_multi_fewshotFR_4/vocab.txt',
#  'Chek1mv_multi_fewshotFR_4/added_tokens.json')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

#Test Dato frances  

path3 = "amazonFR_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_FR = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_FR)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Greens',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.22      0.28        72
#            1       0.42      0.18      0.25        78
#            2       0.28      0.19      0.23        62
#            3       0.51      0.31      0.38        98
#            4       0.67      0.63      0.65       103
#            5       0.19      0.12      0.14        26
#            6       0.69      0.65      0.67        17
#            7       0.10      0.01      0.02        79
#            8       0.06      0.02      0.03       112
#            9       0.00      0.00      0.00        59
#           10       0.00      0.00      0.00        13
#           11       0.22      0.42      0.29       365
#           12       0.11      0.11      0.11       146
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00        34
#           15       0.00      0.00      0.00       100
#           16       0.07      0.03      0.04        64
#           17       0.00      0.00      0.00        31
#           18       0.00      0.00      0.00        21
#           19       0.00      0.00      0.00        72
#           20       0.00      0.00      0.00        48
#           21       0.27      0.38      0.32       133
#           22       0.00      0.00      0.00        41
#           23       0.31      0.50      0.38        68
#           24       0.00      0.00      0.00        27
#           25       0.08      0.08      0.08        97
#           26       0.27      0.34      0.30       164
#           27       0.06      0.05      0.05        22
#           28       0.00      0.00      0.00        11
#           29       0.32      0.62      0.42       321
#           30       0.00      0.00      0.00         0
#
#     accuracy                           0.27      2500
#    macro avg       0.16      0.16      0.15      2500
# weighted avg       0.22      0.27      0.23      2500
#
# {'test_loss': 2.776228427886963, 'test_accuracy': 0.2704, 'test_f1': 0.22681263120262724, 'test_precision': 0.21774919693415637, 'test_recall': 0.2704, 'test_runtime': 44.1334, 'test_samples_per_second': 56.646, 'test_mem_cpu_alloc_delta': 3018752, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 0, 'test_mem_gpu_peaked_delta': 774225408}

# %% [markdown]
# ## Save Model

# %%
# !ls drive/MyDrive/TFG_1/Modelos_entrenados/

# %%
# saving the fine tuned model & tokenizer
model_path = "drive/MyDrive/TFG_1/Modelos_entrenados/Category_text_mBERT"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %% [markdown]
# # BertForSequenceClassification - CATEGORÍA
#
# - Clasificación de categorias de productos a partir del review_body + titulo

# %%
RANDOM_SEED=8
MAX_LENGTH=260


## CLASES DEL CLASIFICADOR 

class_names = df_train.product_category.unique().tolist()

# %%
#TOKENIZAMOS LOS DATAFRAMES

train_encodings = tokenizer(df_train.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_encodings = tokenizer(df_valid.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

# %%
class GPReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_labels = df_train.product_category_cod.values
val_labels = df_valid.product_category_cod.values
test_labels = df_test.product_category_cod.values

# %%
train_data = GPReviewDataset(train_encodings, torch.from_numpy(train_labels))
val_data = GPReviewDataset(val_encodings, torch.from_numpy(val_labels))
test_data = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

# %%
model = BertForSequenceClassification.from_pretrained(
    PRE_TRAINED_MODEL_NAME, # Use the 12-layer BERT model, with an uncased vocab.,
    num_labels = len(class_names), # The number of output labels--2 for binary classification.  si pones num_labels=1 hace MSE LOSS
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False ,# Whether the model returns all hidden-states.   
    vocab_size=tokenizer.vocab_size)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %% [markdown]
# ## Training

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + DE - Category_body_title'   # name of the W&B run
)


trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,
    compute_metrics = compute_metrics            # evaluation dataset
)

trainer.train()
# Out:
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + DE - Category_body_title</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/3aj2b03l" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/3aj2b03l</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210412_163544-3aj2b03l</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:50:07, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.891100</td>
#       <td>1.757502</td>
#       <td>0.499600</td>
#       <td>0.486050</td>
#       <td>0.502595</td>
#       <td>0.499600</td>
#       <td>44.793000</td>
#       <td>55.812000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.471200</td>
#       <td>1.653212</td>
#       <td>0.524000</td>
#       <td>0.509523</td>
#       <td>0.521529</td>
#       <td>0.524000</td>
#       <td>44.640000</td>
#       <td>56.004000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.417900</td>
#       <td>1.637198</td>
#       <td>0.542000</td>
#       <td>0.531350</td>
#       <td>0.531622</td>
#       <td>0.542000</td>
#       <td>44.708000</td>
#       <td>55.918000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=1.6563350354538442, metrics={'train_runtime': 35411.3433, 'train_samples_per_second': 0.532, 'total_flos': 1.6732559880972e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 4096, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 0, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 918351872, 'train_mem_gpu_alloc_delta': 2885137920, 'train_mem_cpu_peaked_delta': 935321600, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
model_path = "Chek1mv_multi_fewshotDE_5"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_fewshotDE_5/tokenizer_config.json',
#  'Chek1mv_multi_fewshotDE_5/special_tokens_map.json',
#  'Chek1mv_multi_fewshotDE_5/vocab.txt',
#  'Chek1mv_multi_fewshotDE_5/added_tokens.json')

# %% [markdown]
# ## Evaluation inglés

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 01:30]
#     </div>
# {'eval_loss': 1.6371982097625732,
#  'eval_accuracy': 0.542,
#  'eval_f1': 0.5313504046372001,
#  'eval_precision': 0.5316221968061521,
#  'eval_recall': 0.542,
#  'eval_runtime': 44.4419,
#  'eval_samples_per_second': 56.253,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 0,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 0,
#  'eval_mem_gpu_peaked_delta': 774225408}

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Aleman 
path3 = "amazonDE_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

predictions,labels, metrics = trainer.predict(test_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Blues',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.40      0.40       114
#            1       0.21      0.10      0.13        62
#            2       0.29      0.20      0.24        54
#            3       0.53      0.43      0.48       111
#            4       0.62      0.55      0.58        55
#            5       0.13      0.19      0.15        16
#            6       0.44      0.56      0.49        27
#            7       0.77      0.77      0.77        39
#            8       0.18      0.26      0.21        96
#            9       0.29      0.15      0.19       103
#           10       0.17      0.19      0.18        78
#           11       0.65      0.43      0.52        30
#           12       0.30      0.41      0.34       338
#           13       0.25      0.21      0.23       163
#           14       0.00      0.00      0.00        13
#           15       0.29      0.42      0.35        33
#           16       0.19      0.18      0.18        74
#           17       0.33      0.31      0.32        98
#           18       0.42      0.24      0.31        41
#           19       0.12      0.17      0.14        12
#           20       0.26      0.29      0.28        51
#           21       0.19      0.22      0.20        68
#           22       0.41      0.33      0.36       106
#           23       0.00      0.00      0.00        35
#           24       0.48      0.40      0.44        70
#           25       0.44      0.49      0.46        47
#           26       0.23      0.21      0.22       154
#           27       0.34      0.30      0.32       120
#           28       0.56      0.31      0.40        16
#           29       0.50      0.60      0.55        30
#           30       0.40      0.50      0.44       246
#
#     accuracy                           0.33      2500
#    macro avg       0.33      0.32      0.32      2500
# weighted avg       0.33      0.33      0.33      2500
#
# {'test_loss': 2.5336315631866455, 'test_accuracy': 0.3312, 'test_f1': 0.3255759803976135, 'test_precision': 0.3313386401807606, 'test_recall': 0.3312, 'test_runtime': 44.6248, 'test_samples_per_second': 56.023, 'test_mem_cpu_alloc_delta': 0, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 0, 'test_mem_gpu_peaked_delta': 774225408}

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + ES - Category_body_title'   # name of the W&B run
)


trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,
    compute_metrics = compute_metrics            # evaluation dataset
)

trainer.train()
# Out:
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + ES - Category_body_title</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/3etbgpu7" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/3etbgpu7</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210413_080332-3etbgpu7</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:50:50, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.879600</td>
#       <td>1.780624</td>
#       <td>0.488000</td>
#       <td>0.477631</td>
#       <td>0.498706</td>
#       <td>0.488000</td>
#       <td>44.718000</td>
#       <td>55.906000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.508100</td>
#       <td>1.663595</td>
#       <td>0.526400</td>
#       <td>0.512326</td>
#       <td>0.524547</td>
#       <td>0.526400</td>
#       <td>44.682800</td>
#       <td>55.950000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.459900</td>
#       <td>1.639476</td>
#       <td>0.542800</td>
#       <td>0.532309</td>
#       <td>0.532226</td>
#       <td>0.542800</td>
#       <td>44.674000</td>
#       <td>55.961000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=1.671131776723464, metrics={'train_runtime': 35454.9804, 'train_samples_per_second': 0.532, 'total_flos': 1.6732559880972e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 4096, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 0, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 984862720, 'train_mem_gpu_alloc_delta': 2885137920, 'train_mem_cpu_peaked_delta': 871387136, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
model_path = "Chek1mv_multi_fewshotES_5"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_fewshotES_5/tokenizer_config.json',
#  'Chek1mv_multi_fewshotES_5/special_tokens_map.json',
#  'Chek1mv_multi_fewshotES_5/vocab.txt',
#  'Chek1mv_multi_fewshotES_5/added_tokens.json')

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='60' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 1:06:51]
#     </div>
# {'eval_loss': 1.6394755840301514,
#  'eval_accuracy': 0.5428,
#  'eval_f1': 0.5323090493176021,
#  'eval_precision': 0.5322263717611002,
#  'eval_recall': 0.5428,
#  'eval_runtime': 44.5454,
#  'eval_samples_per_second': 56.123,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': -63803392,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 63803392,
#  'eval_mem_gpu_peaked_delta': 774225408}

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report


#Test Dato español  

path3 = "amazonES_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_ES)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Oranges',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.32      0.21      0.26        75
#            1       0.52      0.15      0.23        93
#            2       0.60      0.06      0.11        49
#            3       0.23      0.28      0.26        78
#            4       0.52      0.56      0.54        61
#            5       0.33      0.07      0.11        44
#            6       0.75      0.57      0.65        21
#            7       0.06      0.02      0.03        59
#            8       0.36      0.19      0.25       136
#            9       0.00      0.00      0.00        57
#           10       0.00      0.00      0.00        16
#           11       0.18      0.45      0.26       354
#           12       0.10      0.06      0.08       146
#           13       0.00      0.00      0.00        21
#           14       0.00      0.00      0.00        30
#           15       0.00      0.00      0.00        87
#           16       0.16      0.06      0.08        52
#           17       0.00      0.00      0.00        44
#           18       0.00      0.00      0.00        15
#           19       0.00      0.00      0.00        58
#           20       0.00      0.00      0.00        40
#           21       0.26      0.13      0.18       151
#           22       0.00      0.00      0.00        37
#           23       0.00      0.00      0.00        52
#           24       0.07      0.04      0.05        28
#           25       0.07      0.04      0.05       185
#           26       0.26      0.16      0.20       166
#           27       0.14      0.18      0.16        22
#           28       0.00      0.00      0.00        19
#           29       0.26      0.65      0.37       304
#           30       0.00      0.00      0.00         0
#
#     accuracy                           0.22      2500
#    macro avg       0.17      0.13      0.12      2500
# weighted avg       0.20      0.22      0.18      2500
#
# {'test_loss': 2.9002859592437744, 'test_accuracy': 0.224, 'test_f1': 0.1791001525127151, 'test_precision': 0.20084949076070116, 'test_recall': 0.224, 'test_runtime': 44.166, 'test_samples_per_second': 56.605, 'test_mem_cpu_alloc_delta': 0, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 36864, 'test_mem_gpu_peaked_delta': 774225408}

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN + FR - Category_body_title'   # name of the W&B run
)


trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,
    compute_metrics = compute_metrics            # evaluation dataset
)

trainer.train()
# Out:
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN + FR - Category_body_title</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/15irsbts" target="_blank">https://wandb.ai/lucialarraona/CLASSIFICATION%20mBERT%20fewshot/runs/15irsbts</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210413_192757-15irsbts</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18846' max='18846' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18846/18846 9:50:14, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.871900</td>
#       <td>1.761298</td>
#       <td>0.498800</td>
#       <td>0.488406</td>
#       <td>0.511343</td>
#       <td>0.498800</td>
#       <td>44.690200</td>
#       <td>55.941000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.457000</td>
#       <td>1.673085</td>
#       <td>0.524400</td>
#       <td>0.509919</td>
#       <td>0.523172</td>
#       <td>0.524400</td>
#       <td>44.735300</td>
#       <td>55.884000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.399700</td>
#       <td>1.649920</td>
#       <td>0.534000</td>
#       <td>0.522954</td>
#       <td>0.525685</td>
#       <td>0.534000</td>
#       <td>44.745100</td>
#       <td>55.872000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18846, training_loss=1.6596737431705624, metrics={'train_runtime': 35419.171, 'train_samples_per_second': 0.532, 'total_flos': 1.6732559880972e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 0, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 0, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 1117233152, 'train_mem_gpu_alloc_delta': 2885137920, 'train_mem_cpu_peaked_delta': 735109120, 'train_mem_gpu_peaked_delta': 3937148416})

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 01:38]
#     </div>
# {'eval_loss': 1.6499203443527222,
#  'eval_accuracy': 0.534,
#  'eval_f1': 0.5229543604238592,
#  'eval_precision': 0.5256854304731805,
#  'eval_recall': 0.534,
#  'eval_runtime': 44.4939,
#  'eval_samples_per_second': 56.187,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 0,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 0,
#  'eval_mem_gpu_peaked_delta': 774225408}

# %%
model_path = "Chek1mv_multi_fewshotFR_5"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_fewshotFR_5/tokenizer_config.json',
#  'Chek1mv_multi_fewshotFR_5/special_tokens_map.json',
#  'Chek1mv_multi_fewshotFR_5/vocab.txt',
#  'Chek1mv_multi_fewshotFR_5/added_tokens.json')

# %%
#Test Dato frances  
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report


path3 = "amazonFR_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_FR = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_FR)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Greens',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.17      0.23        72
#            1       0.33      0.19      0.24        78
#            2       0.28      0.18      0.22        62
#            3       0.46      0.22      0.30        98
#            4       0.68      0.63      0.65       103
#            5       0.40      0.15      0.22        26
#            6       0.56      0.82      0.67        17
#            7       0.09      0.01      0.02        79
#            8       0.05      0.02      0.03       112
#            9       0.00      0.00      0.00        59
#           10       0.00      0.00      0.00        13
#           11       0.22      0.45      0.29       365
#           12       0.12      0.13      0.12       146
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00        34
#           15       0.07      0.01      0.02       100
#           16       0.08      0.06      0.07        64
#           17       0.00      0.00      0.00        31
#           18       0.00      0.00      0.00        21
#           19       0.00      0.00      0.00        72
#           20       0.00      0.00      0.00        48
#           21       0.28      0.28      0.28       133
#           22       0.00      0.00      0.00        41
#           23       0.37      0.37      0.37        68
#           24       0.00      0.00      0.00        27
#           25       0.10      0.09      0.09        97
#           26       0.22      0.25      0.23       164
#           27       0.03      0.05      0.04        22
#           28       0.00      0.00      0.00        11
#           29       0.34      0.62      0.44       321
#           30       0.00      0.00      0.00         0
#
#     accuracy                           0.26      2500
#    macro avg       0.16      0.15      0.15      2500
# weighted avg       0.22      0.26      0.22      2500
#
# {'test_loss': 2.798637628555298, 'test_accuracy': 0.2592, 'test_f1': 0.22000015485193272, 'test_precision': 0.21667791068320139, 'test_recall': 0.2592, 'test_runtime': 44.6493, 'test_samples_per_second': 55.992, 'test_mem_cpu_alloc_delta': 0, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 0, 'test_mem_gpu_peaked_delta': 774225408}

# %% [markdown]
# ## Save Model

# %%
# !ls drive/MyDrive/TFG_1/Modelos_entrenados/

# %%
# saving the fine tuned model & tokenizer
model_path = "drive/MyDrive/TFG_1/Modelos_entrenados/Category_text_title_mBERT"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
