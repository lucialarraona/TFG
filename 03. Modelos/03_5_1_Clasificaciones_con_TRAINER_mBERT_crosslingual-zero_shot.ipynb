# %% [markdown]
# # Librerias

# %%
import torch
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Fri Apr  2 09:48:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           On   | 00000001:00:00.0 Off |                    0 |
# | N/A   56C    P8    59W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla K80           On   | 00000002:00:00.0 Off |                    0 |
# | N/A   42C    P8    34W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %%capture 
# !pip install transformers -U
#!pip install pytorch

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.4.2
# Summary: State-of-the-art Natural Language Processing for TensorFlow 2.0 and PyTorch
# Home-page: https://github.com/huggingface/transformers
# Author: Thomas Wolf, Lysandre Debut, Victor Sanh, Julien Chaumond, Sam Shleifer, Patrick von Platen, Sylvain Gugger, Google AI Language Team Authors, Open AI team Authors, Facebook AI Authors, Carnegie Mellon University Authors
# Author-email: thomas@huggingface.co
# License: Apache
# Location: /anaconda/envs/py37_pytorch/lib/python3.7/site-packages
# Requires: requests, tqdm, sacremoses, numpy, packaging, regex, tokenizers, filelock, importlib-metadata
# Required-by: bertviz

# %%
from sklearn.model_selection import train_test_split
import torch

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %%capture
# !pip install wandb
import wandb
wandb.login()

# %%
wandb.login()
# Out:
# True

# %% [markdown]
# # Carga de datos
# - incluidas nuevas columnas con concatenacion de review_body y categoria, review_body y titulo
# - nuevos indices para star rating, de 0-4 en vez de 1-5
# - numericalizar las categorias de los productos, 31 en total
#
# Para TRAIN:
#   - data ingles EN
#   - data aleman DE
#
# Para VALID Y TEST:
#   - data en ingles EN
#   - data en aleman DE
#   - data en español ES
#   - data en francés FR
#   - data en japones JA
#   - data en chino ZH

# %%
# Load data
import pandas as pd

## Para TRAIN, en ingles
path1 = "amazonEN_train.csv"

## Para VALID, en ingles
path2 = "amazonEN_valid.csv"

## Para TEST, en ingles, aleman, español, frances, japones y chino
path3 = "amazonDE_test.csv"

####### CONVERTIMOS A DATAFRAMES #########

df_train = pd.read_csv(path1)
df_train = df_train

df_valid = pd.read_csv(path2)
df_valid = df_valid

df_test = pd.read_csv(path3)
df_test = df_test

# %%
df_train.head(1)
# Out:
#     review_id          product_id          reviewer_id  star_rating  \
# 0  en_0953486  product_en_0381770  reviewer_en_0978532            4
#
#                                          review_body  \
# 0  Great, great batteries. Arrived on time and pa...
#
#                                 review_title language product_category  \
# 0  Strip of 10 Fresh Maxell LR1130 Batteries       en      electronics
#
#                                           text_title  \
# 0  Strip of 10 Fresh Maxell LR1130 Batteries Grea...
#
#                                       text_title_cat  \
# 0  Strip of 10 Fresh Maxell LR1130 Batteries Grea...
#
#                                             text_cat  product_category_cod
# 0  Great, great batteries. Arrived on time and pa...                     9

# %% [markdown]
# # Carga modelo mBERT
# - incluye tokenizer

# %%
PRE_TRAINED_MODEL_NAME = 'bert-base-multilingual-cased'
from transformers import BertModel, BertConfig, BertTokenizer
from transformers import BertForSequenceClassification
tokenizer = BertTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)

# %% [markdown]
# # mBertForSequenceClassification - RATING
# - Clasificación Rating a partir de review_body

# %%
# %env WANDB_PROJECT = RATING CLASSIFICATION mBERT
# Out:
# env: WANDB_PROJECT=RATING CLASSIFICATION mBERT

# %%
# %env WANDB_WATCH = 'all'
# Out:
# env: WANDB_WATCH='all'

# %%
RANDOM_SEED=8
MAX_LENGTH=260


## CLASES DEL CLASIFICADOR 

class_names = ['0','1','2','3','4']

# %%
RANDOM_SEED=8
MAX_LENGTH=260


train_encodings = tokenizer(df_train.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_encodings = tokenizer(df_valid.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_encodings = tokenizer(df_test.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

# %%
class AMZReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_labels = df_train.star_rating.values
val_labels = df_valid.star_rating.values
test_labels = df_test.star_rating.values

# %%
train_data = AMZReviewDataset(train_encodings, torch.from_numpy(train_labels))
val_data = AMZReviewDataset(val_encodings, torch.from_numpy(val_labels))
test_data = AMZReviewDataset(test_encodings, torch.from_numpy(test_labels))

# %%
from transformers import BertForSequenceClassification

## DEFINIMOS EL MODELO 

model = BertForSequenceClassification.from_pretrained(
    PRE_TRAINED_MODEL_NAME,         # Use the 12-layer BERT model, with an uncased vocab.
    #'Chek4mv_multi',
    num_labels = len(class_names),  # The number of output labels--2 for binary classification.
    output_attentions = False,      # Whether the model returns attentions weights.
    output_hidden_states = False ,  # Whether the model returns all hidden-states.   
    vocab_size=tokenizer.vocab_size)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Training

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
#from datasets import load_metric
#import numpy as np

#accuracy_metric = load_metric("accuracy")

#def compute_metrics(eval_pred):
 #   predictions, labels = eval_pred
  #  predictions = np.argmax(predictions, axis=1)
    # metrics from the datasets library have a `compute` method
    #  return accuracy_metric.compute(predictions=predictions, references=labels)

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,                  # total number of training epochs
    per_device_train_batch_size=8,       # batch size per device during training
    per_device_eval_batch_size=16,       # batch size for evaluation
    warmup_steps=500,                    # number of warmup steps for learning rate scheduler
    weight_decay=0.01,                   # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',       # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',                # enable logging to W&B
    run_name = 'EN - DE'                 # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset
    eval_dataset = test_data,              # evaluation dataset
    compute_metrics=compute_metrics            
)

trainer.train()
# Out:
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN - DE</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/3iski5le" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/3iski5le</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210329_111328-3iski5le</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='12502' max='37500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12502/37500 6:10:15 < 12:20:27, 0.56 it/s, Epoch 1.00/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.976000</td>
#       <td>1.019836</td>
#       <td>0.554400</td>
#       <td>0.557216</td>
#       <td>0.566414</td>
#       <td>0.554400</td>
#       <td>92.529800</td>
#       <td>27.018000</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-49413b62dae0> in <module>
#      27 )
#      28
# ---> 29 trainer.train()
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, **kwargs)
#    1051                         tr_loss += self.training_step(model, inputs)
#    1052                 else:
# -> 1053                     tr_loss += self.training_step(model, inputs)
#    1054                 self._total_flos += float(self.floating_point_ops(inputs))
#    1055
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/trainer.py in training_step(self, model, inputs)
#    1441                 loss = self.compute_loss(model, inputs)
#    1442         else:
# -> 1443             loss = self.compute_loss(model, inputs)
#    1444
#    1445         if self.args.n_gpu > 1:
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs)
#    1473         else:
#    1474             labels = None
# -> 1475         outputs = model(**inputs)
#    1476         # Save past state if it exists
#    1477         # TODO: this needs to be fixed and made cleaner later.
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     159             return self.module(*inputs[0], **kwargs[0])
#     160         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# --> 161         outputs = self.parallel_apply(replicas, inputs, kwargs)
#     162         return self.gather(outputs, self.output_device)
#     163
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in parallel_apply(self, replicas, inputs, kwargs)
#     169
#     170     def parallel_apply(self, replicas, inputs, kwargs):
# --> 171         return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#     172
#     173     def gather(self, outputs, output_device):
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/parallel/parallel_apply.py in parallel_apply(modules, inputs, kwargs_tup, devices)
#      84         output = results[i]
#      85         if isinstance(output, ExceptionWrapper):
# ---> 86             output.reraise()
#      87         outputs.append(output)
#      88     return outputs
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/_utils.py in reraise(self)
#     426             # have message field
#     427             raise self.exc_type(message=msg)
# --> 428         raise self.exc_type(msg)
#     429
#     430
#
# RuntimeError: Caught RuntimeError in replica 1 on device 1.
# Original Traceback (most recent call last):
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/parallel/parallel_apply.py", line 61, in _worker
#     output = module(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 1510, in forward
#     return_dict=return_dict,
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 981, in forward
#     return_dict=return_dict,
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 575, in forward
#     output_attentions,
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 497, in forward
#     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/modeling_utils.py", line 1819, in apply_chunking_to_forward
#     return forward_fn(*input_tensors)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 508, in feed_forward_chunk
#     intermediate_output = self.intermediate(attention_output)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 412, in forward
#     hidden_states = self.intermediate_act_fn(hidden_states)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/functional.py", line 1383, in gelu
#     return torch._C._nn.gelu(input)
# RuntimeError: CUDA out of memory. Tried to allocate 48.00 MiB (GPU 1; 11.17 GiB total capacity; 7.27 GiB already allocated; 27.44 MiB free; 7.38 GiB reserved in total by PyTorch)

# %%
model_path = "Chek1mv_multi"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi/tokenizer_config.json',
#  'Chek1mv_multi/special_tokens_map.json',
#  'Chek1mv_multi/vocab.txt',
#  'Chek1mv_multi/added_tokens.json')

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=1,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN - DE'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,           # training dataset
    eval_dataset = test_data,             # evaluation dataset
    compute_metrics=compute_metrics            
)

trainer.train("drive/MyDrive/TFG_1/Checkpoints/Chek1mv_multi")
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='6250' max='6250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6250/6250 3:16:42, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.913100</td>
#       <td>0.950955</td>
#       <td>0.577200</td>
#       <td>0.572664</td>
#       <td>0.571422</td>
#       <td>0.577200</td>
#       <td>43.394300</td>
#       <td>57.611000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=6250, training_loss=1.0368619778442383, metrics={'train_runtime': 11804.8167, 'train_samples_per_second': 0.529, 'total_flos': 5.549147292e+16, 'epoch': 1.0, 'init_mem_cpu_alloc_delta': 2106217, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 1064799839, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 12892669, 'train_mem_gpu_alloc_delta': 2885308928, 'train_mem_cpu_peaked_delta': 734423176, 'train_mem_gpu_peaked_delta': 3937049088})

# %%
model_path = "Chek2mv_multi"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek2mv_multi/tokenizer_config.json',
#  'Chek2mv_multi/special_tokens_map.json',
#  'Chek2mv_multi/vocab.txt',
#  'Chek2mv_multi/added_tokens.json')

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=1,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN - DE'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,           # training dataset
    eval_dataset = test_data,             # evaluation dataset
    compute_metrics=compute_metrics            
)

trainer.train("drive/MyDrive/TFG_1/Checkpoints/Chek2mv_multi")
# Out:
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN - DE</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/rkruldva" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/rkruldva</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210330_154929-rkruldva</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='6250' max='6250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6250/6250 3:18:05, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.917800</td>
#       <td>0.948830</td>
#       <td>0.580800</td>
#       <td>0.576185</td>
#       <td>0.574535</td>
#       <td>0.580800</td>
#       <td>43.431200</td>
#       <td>57.562000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=6250, training_loss=1.038168766479492, metrics={'train_runtime': 11889.265, 'train_samples_per_second': 0.526, 'total_flos': 5.549147292e+16, 'epoch': 1.0, 'init_mem_cpu_alloc_delta': 67058, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 13316381, 'train_mem_gpu_alloc_delta': 2884997632, 'train_mem_cpu_peaked_delta': 734412258, 'train_mem_gpu_peaked_delta': 3937049088})

# %%
model_path = "Chek3mv_multi"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek3mv_multi/tokenizer_config.json',
#  'Chek3mv_multi/special_tokens_map.json',
#  'Chek3mv_multi/vocab.txt',
#  'Chek3mv_multi/added_tokens.json')

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=2,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN - DE'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,           # training dataset
    eval_dataset = test_data,             # evaluation dataset
    compute_metrics=compute_metrics            
)

trainer.train("Chek3mv_multi")
# Out:
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN - DE</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/ekux6f27" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/ekux6f27</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210330_215625-ekux6f27</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='12500' max='12500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12500/12500 6:36:09, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.976200</td>
#       <td>0.970453</td>
#       <td>0.577600</td>
#       <td>0.570336</td>
#       <td>0.571102</td>
#       <td>0.577600</td>
#       <td>43.424900</td>
#       <td>57.571000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.834500</td>
#       <td>0.952905</td>
#       <td>0.588400</td>
#       <td>0.585299</td>
#       <td>0.583591</td>
#       <td>0.588400</td>
#       <td>43.285700</td>
#       <td>57.756000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=12500, training_loss=0.8972144152832031, metrics={'train_runtime': 23774.2108, 'train_samples_per_second': 0.526, 'total_flos': 1.1098294584e+17, 'epoch': 2.0, 'init_mem_cpu_alloc_delta': 67058, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 27065773, 'train_mem_gpu_alloc_delta': 3597020160, 'train_mem_cpu_peaked_delta': 734496426, 'train_mem_gpu_peaked_delta': 3937049088})

# %%
model_path = "Chek4mv_multi"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek4mv_multi/tokenizer_config.json',
#  'Chek4mv_multi/special_tokens_map.json',
#  'Chek4mv_multi/vocab.txt',
#  'Chek4mv_multi/added_tokens.json')

# %%
#wandb.init(project="mBERT", 
#                name = "mbert",
#                tags = ['rating'],
#                group = "mbert_body_rating")

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=2,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN - DE'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,           # training dataset
    eval_dataset = test_data,             # evaluation dataset
    compute_metrics=compute_metrics            
)

trainer.train("Chek4mv_multi")
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN - DE</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/1qk0464y" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/1qk0464y</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210331_085550-1qk0464y</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='12500' max='12500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12500/12500 6:40:45, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.976200</td>
#       <td>0.970453</td>
#       <td>0.577600</td>
#       <td>0.570336</td>
#       <td>0.571102</td>
#       <td>0.577600</td>
#       <td>44.906200</td>
#       <td>55.672000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.834500</td>
#       <td>0.952905</td>
#       <td>0.588400</td>
#       <td>0.585299</td>
#       <td>0.583591</td>
#       <td>0.588400</td>
#       <td>44.712400</td>
#       <td>55.913000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=12500, training_loss=0.8972144152832031, metrics={'train_runtime': 24049.5862, 'train_samples_per_second': 0.52, 'total_flos': 1.1098294584e+17, 'epoch': 2.0, 'init_mem_cpu_alloc_delta': 66919, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 27071605, 'train_mem_gpu_alloc_delta': 3597020160, 'train_mem_cpu_peaked_delta': 734495907, 'train_mem_gpu_peaked_delta': 3937049088})

# %% [markdown]
# ## Evaluation sobre dato en idioma de entrenamiento (inglés)

# %%
trainer.evaluate()

# %% [markdown]
# ## Test sobre dato en otros idiomas

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Aleman 
predictions,labels, metrics = trainer.predict(val_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Blues',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.40      0.49       479
#            1       0.38      0.44      0.41       513
#            2       0.34      0.58      0.43       512
#            3       0.42      0.42      0.42       493
#            4       0.70      0.34      0.46       503
#
#     accuracy                           0.44      2500
#    macro avg       0.50      0.43      0.44      2500
# weighted avg       0.49      0.44      0.44      2500
#
# {'eval_loss': 1.3517433404922485, 'eval_accuracy': 0.4356, 'eval_f1': 0.43968140412768236, 'eval_precision': 0.49308058527736137, 'eval_recall': 0.4356, 'eval_runtime': 43.3109, 'eval_samples_per_second': 57.722, 'test_mem_cpu_alloc_delta': 170463, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 766274, 'test_mem_gpu_peaked_delta': 773972480}

# %%
#Test Dato español  

path3 = "amazonES_valid.csv"
df_valid = pd.read_csv(path3)
df_valid = df_valid

val_encodings = tokenizer(df_valid.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_labels = df_valid.star_rating.values
val_data_ES = GPReviewDataset(val_encodings, torch.from_numpy(val_labels))

# %%
## valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(val_data_ES)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Oranges',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.55      0.61       502
#            1       0.43      0.36      0.39       503
#            2       0.41      0.49      0.44       497
#            3       0.45      0.43      0.44       503
#            4       0.61      0.72      0.66       495
#
#     accuracy                           0.51      2500
#    macro avg       0.51      0.51      0.51      2500
# weighted avg       0.51      0.51      0.51      2500
#
# {'eval_loss': 1.1444693803787231, 'eval_accuracy': 0.51, 'eval_f1': 0.508005889817473, 'eval_precision': 0.5130164858438848, 'eval_recall': 0.51, 'eval_runtime': 43.4588, 'eval_samples_per_second': 57.526, 'test_mem_cpu_alloc_delta': 174707, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 763885, 'test_mem_gpu_peaked_delta': 773972480}

# %%
#Test Dato frances  

path3 = "amazonFR_valid.csv"
df_valid = pd.read_csv(path3)
df_valid = df_valid

val_encodings = tokenizer(df_valid.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_labels = df_valid.star_rating.values
val_data_FR = GPReviewDataset(val_encodings, torch.from_numpy(val_labels))

# %%
## valid data en FRANCES
predictions,labels, metrics = trainer.predict(val_data_FR)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Greens',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.54      0.59       503
#            1       0.41      0.33      0.36       490
#            2       0.35      0.43      0.39       493
#            3       0.41      0.46      0.44       512
#            4       0.62      0.61      0.61       502
#
#     accuracy                           0.48      2500
#    macro avg       0.49      0.47      0.48      2500
# weighted avg       0.49      0.48      0.48      2500
#
# {'eval_loss': 1.2378034591674805, 'eval_accuracy': 0.4756, 'eval_f1': 0.4779166914729096, 'eval_precision': 0.4861928983438436, 'eval_recall': 0.4756, 'eval_runtime': 43.4094, 'eval_samples_per_second': 57.591, 'test_mem_cpu_alloc_delta': 171537, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 768049, 'test_mem_gpu_peaked_delta': 773972480}

# %% [markdown]
# ## Save Model final

# %%
# !ls drive/MyDrive/TFG_1/Modelos_entrenados/

# %%
# saving the fine tuned model & tokenizer
model_path = "Rating_text_mBERT_final"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %% [markdown]
# # mBertForSequenceClassification - RATING
# - Clasificación Rating a partir de review_body + titulo

# %%
RANDOM_SEED=8
MAX_LENGTH=260


## CLASES DEL CLASIFICADOR 

class_names = ['0','1','2','3','4']

# %%
#TOKENIZAMOS LOS DATAFRAMES

train_encodings = tokenizer(df_train.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_encodings = tokenizer(df_valid.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

# %%
class GPReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_labels = df_train.star_rating.values
val_labels = df_valid.star_rating.values
test_labels = df_test.star_rating.values

# %%
train_data = GPReviewDataset(train_encodings, torch.from_numpy(train_labels))
val_data = GPReviewDataset(val_encodings, torch.from_numpy(val_labels))
test_data = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

# %%
## Lo definimos de nuevo unicamente con el proposito de usar las secciones del documento de forma independiente 

model = BertForSequenceClassification.from_pretrained(
    PRE_TRAINED_MODEL_NAME, # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = len(class_names), # The number of output labels--2 for binary classification.  si pones num_labels=1 hace MSE LOSS
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False ,# Whether the model returns all hidden-states.   
    vocab_size=tokenizer.vocab_size)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %% [markdown]
# ## Training

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN-body_title-rating'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset en inles
    eval_dataset = val_data,               # evaluation dataset en ingles
    compute_metrics=compute_metrics                   
)

trainer.train()
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN-body_title-rating</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/139a2f88" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/139a2f88</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210331_183938-139a2f88</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18750' max='18750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18750/18750 10:04:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.801600</td>
#       <td>0.852742</td>
#       <td>0.636800</td>
#       <td>0.638591</td>
#       <td>0.648434</td>
#       <td>0.636800</td>
#       <td>44.720100</td>
#       <td>55.903000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.772600</td>
#       <td>0.838883</td>
#       <td>0.636400</td>
#       <td>0.635148</td>
#       <td>0.642136</td>
#       <td>0.636400</td>
#       <td>44.528500</td>
#       <td>56.144000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.680500</td>
#       <td>0.857142</td>
#       <td>0.646400</td>
#       <td>0.646676</td>
#       <td>0.647721</td>
#       <td>0.646400</td>
#       <td>44.380000</td>
#       <td>56.332000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18750, training_loss=0.789291808573405, metrics={'train_runtime': 36263.617, 'train_samples_per_second': 0.517, 'total_flos': 1.6647441876e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 67058, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 40806060, 'train_mem_gpu_alloc_delta': 2884997632, 'train_mem_cpu_peaked_delta': 734428000, 'train_mem_gpu_peaked_delta': 3937049088})

# %%
model_path = "Chek1mv_multi_2"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_2/tokenizer_config.json',
#  'Chek1mv_multi_2/special_tokens_map.json',
#  'Chek1mv_multi_2/vocab.txt',
#  'Chek1mv_multi_2/added_tokens.json')

# %% [markdown]
# ## Evaluation en ingles

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='100' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 3:34:03]
#     </div>
# wandb: WARNING Step must only increase in log calls.  Step 18750 < 18751; dropping {'eval/loss': 0.8388826251029968, 'eval/accuracy': 0.6364, 'eval/f1': 0.6351479462238594, 'eval/precision': 0.6421361654494046, 'eval/recall': 0.6364, 'eval/runtime': 44.3356, 'eval/samples_per_second': 56.388, 'train/epoch': 3.0}.
# {'eval_loss': 0.8388826251029968,
#  'eval_accuracy': 0.6364,
#  'eval_f1': 0.6351479462238594,
#  'eval_precision': 0.6421361654494046,
#  'eval_recall': 0.6364,
#  'eval_runtime': 44.3356,
#  'eval_samples_per_second': 56.388,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 180146,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 756197,
#  'eval_mem_gpu_peaked_delta': 773972480}

# %% [markdown]
# ## Test en otros idiomas

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Aleman 
predictions,labels, metrics = trainer.predict(test_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Blues',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.42      0.53       521
#            1       0.36      0.42      0.39       487
#            2       0.30      0.76      0.43       488
#            3       0.40      0.19      0.26       507
#            4       0.74      0.24      0.37       497
#
#     accuracy                           0.40      2500
#    macro avg       0.50      0.41      0.39      2500
# weighted avg       0.51      0.40      0.39      2500
#
# {'eval_loss': 1.4870661497116089, 'eval_accuracy': 0.4036, 'eval_f1': 0.39486898418167027, 'eval_precision': 0.5066604560258099, 'eval_recall': 0.4036, 'eval_runtime': 44.5045, 'eval_samples_per_second': 56.174, 'test_mem_cpu_alloc_delta': 172359, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 764143, 'test_mem_gpu_peaked_delta': 773972480}

# %%
#Test Dato español  

path3 = "amazonES_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.star_rating.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_ES)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Oranges',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.60      0.62       498
#            1       0.45      0.27      0.34       497
#            2       0.37      0.59      0.46       503
#            3       0.43      0.34      0.38       497
#            4       0.59      0.65      0.62       505
#
#     accuracy                           0.49      2500
#    macro avg       0.50      0.49      0.49      2500
# weighted avg       0.50      0.49      0.49      2500
#
# {'eval_loss': 1.1456836462020874, 'eval_accuracy': 0.492, 'eval_f1': 0.4854591563922186, 'eval_precision': 0.5013836550201961, 'eval_recall': 0.492, 'eval_runtime': 44.3119, 'eval_samples_per_second': 56.418, 'test_mem_cpu_alloc_delta': 167727, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 770680, 'test_mem_gpu_peaked_delta': 773972480}

# %%
#Test Dato frances  

path3 = "amazonFR_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.star_rating.values
test_data_FR = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_FR)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Greens',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.54      0.58       497
#            1       0.45      0.23      0.31       510
#            2       0.33      0.66      0.44       507
#            3       0.42      0.37      0.39       488
#            4       0.68      0.53      0.59       498
#
#     accuracy                           0.46      2500
#    macro avg       0.50      0.46      0.46      2500
# weighted avg       0.50      0.46      0.46      2500
#
# {'eval_loss': 1.210147500038147, 'eval_accuracy': 0.4644, 'eval_f1': 0.4627322638535933, 'eval_precision': 0.503010212381473, 'eval_recall': 0.4644, 'eval_runtime': 44.4145, 'eval_samples_per_second': 56.288, 'test_mem_cpu_alloc_delta': 170875, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 763464, 'test_mem_gpu_peaked_delta': 773972480}

# %%
#Test Dato inglés (idioma de entrenamiento) 

path3 = "amazonEN_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.star_rating.values
test_data_EN = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_EN)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Purples',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.81      0.71       480
#            1       0.63      0.46      0.53       530
#            2       0.55      0.62      0.59       501
#            3       0.64      0.56      0.60       479
#            4       0.77      0.77      0.77       510
#
#     accuracy                           0.64      2500
#    macro avg       0.64      0.65      0.64      2500
# weighted avg       0.64      0.64      0.64      2500
#
# {'eval_loss': 0.8095430731773376, 'eval_accuracy': 0.6428, 'eval_f1': 0.6382253307109252, 'eval_precision': 0.6445252633266849, 'eval_recall': 0.6428, 'eval_runtime': 43.6054, 'eval_samples_per_second': 57.332, 'test_mem_cpu_alloc_delta': 172534, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 769757, 'test_mem_gpu_peaked_delta': 773972480}

# %% [markdown]
# ## Save Model

# %%
# !ls drive/MyDrive/TFG_1/Modelos_entrenados/

# %%
# saving the fine tuned model & tokenizer
model_path = "drive/MyDrive/TFG_1/Modelos_entrenados/Rating_text_title_mBERT"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %% [markdown]
# # mBertForSequenceClassification - RATING
# - Clasificación Rating a partir de review_body + titulo + categoria

# %%
RANDOM_SEED=8
MAX_LENGTH=260


## CLASES DEL CLASIFICADOR 

class_names = ['0','1','2','3','4'] 
#class_names = ['0','1'] 
#class_names = ['1']

# %%
#TOKENIZAMOS LOS DATAFRAMES

train_encodings = tokenizer(df_train.text_title_cat.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_encodings = tokenizer(df_valid.text_title_cat.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_encodings = tokenizer(df_test.text_title_cat.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

# %%
class GPReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_labels = df_train.star_rating.values
val_labels = df_valid.star_rating.values
test_labels = df_test.star_rating.values

# %%
train_data = GPReviewDataset(train_encodings, torch.from_numpy(train_labels))
val_data = GPReviewDataset(val_encodings, torch.from_numpy(val_labels))
test_data = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

# %%
model = BertForSequenceClassification.from_pretrained(
    PRE_TRAINED_MODEL_NAME, # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = len(class_names), # The number of output labels--2 for binary classification.  si pones num_labels=1 hace MSE LOSS
    output_attentions = False, # Whether the model returns attentions weights. --> importante para la visualización de los pesos de atención
    output_hidden_states = False ,# Whether the model returns all hidden-states.   
    vocab_size=tokenizer.vocab_size)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %% [markdown]
# ## Training

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=1,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN-body_title_cat-rating'   # name of the W&B run

)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,            # training dataset
    eval_dataset = val_data,             # evaluation dataset
    compute_metrics=compute_metrics             
)

trainer.train()
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN-body_title_cat-rating</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/2fgpmnub" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/2fgpmnub</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210401_151252-2fgpmnub</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='6251' max='6250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6250/6250 3:24:15, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='1' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 1/20 : < :]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-01d96fa14f2c> in <module>
#      28 )
#      29
# ---> 30 trainer.train()
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, **kwargs)
#    1109
#    1110             self.control = self.callback_handler.on_epoch_end(self.args, self.state, self.control)
# -> 1111             self._maybe_log_save_evaluate(tr_loss, model, trial, epoch)
#    1112
#    1113             if self.args.tpu_metrics_debug or self.args.debug:
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, model, trial, epoch)
#    1196         metrics = None
#    1197         if self.control.should_evaluate:
# -> 1198             metrics = self.evaluate()
#    1199             self._report_to_hp_search(trial, epoch, metrics)
#    1200
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    1672             prediction_loss_only=True if self.compute_metrics is None else None,
#    1673             ignore_keys=ignore_keys,
# -> 1674             metric_key_prefix=metric_key_prefix,
#    1675         )
#    1676
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/trainer.py in prediction_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    1803
#    1804         for step, inputs in enumerate(dataloader):
# -> 1805             loss, logits, labels = self.prediction_step(model, inputs, prediction_loss_only, ignore_keys=ignore_keys)
#    1806             if loss is not None:
#    1807                 losses = loss.repeat(batch_size)
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/trainer.py in prediction_step(self, model, inputs, prediction_loss_only, ignore_keys)
#    1917         with torch.no_grad():
#    1918             if has_labels:
# -> 1919                 loss, outputs = self.compute_loss(model, inputs, return_outputs=True)
#    1920                 loss = loss.mean().detach()
#    1921                 if isinstance(outputs, dict):
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs)
#    1473         else:
#    1474             labels = None
# -> 1475         outputs = model(**inputs)
#    1476         # Save past state if it exists
#    1477         # TODO: this needs to be fixed and made cleaner later.
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     159             return self.module(*inputs[0], **kwargs[0])
#     160         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# --> 161         outputs = self.parallel_apply(replicas, inputs, kwargs)
#     162         return self.gather(outputs, self.output_device)
#     163
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in parallel_apply(self, replicas, inputs, kwargs)
#     169
#     170     def parallel_apply(self, replicas, inputs, kwargs):
# --> 171         return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#     172
#     173     def gather(self, outputs, output_device):
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/parallel/parallel_apply.py in parallel_apply(modules, inputs, kwargs_tup, devices)
#      84         output = results[i]
#      85         if isinstance(output, ExceptionWrapper):
# ---> 86             output.reraise()
#      87         outputs.append(output)
#      88     return outputs
#
# /anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/_utils.py in reraise(self)
#     426             # have message field
#     427             raise self.exc_type(message=msg)
# --> 428         raise self.exc_type(msg)
#     429
#     430
#
# RuntimeError: Caught RuntimeError in replica 0 on device 0.
# Original Traceback (most recent call last):
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/parallel/parallel_apply.py", line 61, in _worker
#     output = module(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 1510, in forward
#     return_dict=return_dict,
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 981, in forward
#     return_dict=return_dict,
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 575, in forward
#     output_attentions,
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 497, in forward
#     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/modeling_utils.py", line 1819, in apply_chunking_to_forward
#     return forward_fn(*input_tensors)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 508, in feed_forward_chunk
#     intermediate_output = self.intermediate(attention_output)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py", line 412, in forward
#     hidden_states = self.intermediate_act_fn(hidden_states)
#   File "/anaconda/envs/py37_pytorch/lib/python3.7/site-packages/torch/nn/functional.py", line 1383, in gelu
#     return torch._C._nn.gelu(input)
# RuntimeError: CUDA out of memory. Tried to allocate 196.00 MiB (GPU 0; 11.17 GiB total capacity; 9.97 GiB already allocated; 2.81 MiB free; 10.84 GiB reserved in total by PyTorch)

# %%
model_path = "Chek1mv_multi_3"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %% [markdown]
# ## Evaluation en inglés

# %%
trainer.evaluate()

# %% [markdown]
# ## Test en otros idiomas

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Aleman 
predictions,labels, metrics = trainer.predict(test_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Blues',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)

# %%
#Test Dato español  

path3 = "amazonES_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.star_rating.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_ES)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Oranges',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)

# %%
#Test Dato frances  

path3 = "amazonFR_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.star_rating.values
test_data_FR = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_FR)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (10,7))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Greens',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)

# %% [markdown]
# ## Visualización de la atención con BertViz

# %%
# !pip install bertviz

# %%
inputs = tokenizer.encode("I like this product so much", return_tensors='pt')
outputs = model(inputs)
attention = outputs[-1]                      # Output includes attention weights when output_attentions=True
tokens = tokenizer.convert_ids_to_tokens(inputs[0])

# %% [markdown]
# ## Save Model

# %%
# !ls drive/MyDrive/TFG_1/Modelos_entrenados/

# %%
# saving the fine tuned model & tokenizer
model_path = "drive/MyDrive/TFG_1/Modelos_entrenados/Rating_text_title_cat_mBERT"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %% [markdown]
# # BertForSequenceClassification - CATEGORÍA
#
# - Clasificación de categorias de productos a partir del review_body

# %%
RANDOM_SEED=8
MAX_LENGTH=260


## CLASES DEL CLASIFICADOR 

class_names = df_train.product_category.unique().tolist()

# %%
#TOKENIZAMOS LOS DATAFRAMES

train_encodings = tokenizer(df_train.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_encodings = tokenizer(df_valid.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_encodings = tokenizer(df_test.review_body.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

# %%
class GPReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_labels = df_train.product_category_cod.values
val_labels = df_valid.product_category_cod.values
test_labels = df_test.product_category_cod.values

# %%
train_data = GPReviewDataset(train_encodings, torch.from_numpy(train_labels))
val_data = GPReviewDataset(val_encodings, torch.from_numpy(val_labels))
test_data = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

# %%
model = BertForSequenceClassification.from_pretrained(
    PRE_TRAINED_MODEL_NAME, # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = len(class_names), # The number of output labels--2 for binary classification.  si pones num_labels=1 hace MSE LOSS
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False ,# Whether the model returns all hidden-states.   
    vocab_size=tokenizer.vocab_size)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %% [markdown]
# ## Training

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN-body- category'   # name of the W&B run
)

trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,            # evaluation dataset
    compute_metrics = compute_metrics             
)

trainer.train()
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN-body- category</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/1046epjd" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/1046epjd</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210401_200004-1046epjd</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18750' max='18750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18750/18750 9:45:12, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.685700</td>
#       <td>1.828429</td>
#       <td>0.481200</td>
#       <td>0.466035</td>
#       <td>0.491996</td>
#       <td>0.481200</td>
#       <td>44.200900</td>
#       <td>56.560000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.526600</td>
#       <td>1.691959</td>
#       <td>0.519600</td>
#       <td>0.512335</td>
#       <td>0.519157</td>
#       <td>0.519600</td>
#       <td>43.878300</td>
#       <td>56.976000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.507700</td>
#       <td>1.676065</td>
#       <td>0.531200</td>
#       <td>0.518490</td>
#       <td>0.518731</td>
#       <td>0.531200</td>
#       <td>44.177200</td>
#       <td>56.590000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18750, training_loss=1.7168937803649902, metrics={'train_runtime': 35116.6316, 'train_samples_per_second': 0.534, 'total_flos': 1.66493133144e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 67058, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 40813940, 'train_mem_gpu_alloc_delta': 2885237248, 'train_mem_cpu_peaked_delta': 734426769, 'train_mem_gpu_peaked_delta': 3937049088})

# %%
model_path = "Chek1mv_multi_4"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi_4/tokenizer_config.json',
#  'Chek1mv_multi_4/special_tokens_map.json',
#  'Chek1mv_multi_4/vocab.txt',
#  'Chek1mv_multi_4/added_tokens.json')

# %% [markdown]
# ## Evaluation

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='180' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 3:01:30]
#     </div>
# wandb: WARNING Step must only increase in log calls.  Step 18750 < 18751; dropping {'eval/loss': 1.6760646104812622, 'eval/accuracy': 0.5312, 'eval/f1': 0.5184899719621034, 'eval/precision': 0.5187306491375294, 'eval/recall': 0.5312, 'eval/runtime': 43.6083, 'eval/samples_per_second': 57.329, 'train/epoch': 3.0}.
# {'eval_loss': 1.6760646104812622,
#  'eval_accuracy': 0.5312,
#  'eval_f1': 0.5184899719621034,
#  'eval_precision': 0.5187306491375294,
#  'eval_recall': 0.5312,
#  'eval_runtime': 43.6083,
#  'eval_samples_per_second': 57.329,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 440003,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 495649,
#  'eval_mem_gpu_peaked_delta': 774225408}

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Aleman 
path3 = "amazonDE_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

predictions,labels, metrics = trainer.predict(test_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Blues',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.28      0.28       114
#            1       0.23      0.24      0.24        62
#            2       0.38      0.20      0.27        54
#            3       0.60      0.36      0.45       111
#            4       0.38      0.56      0.46        55
#            5       0.12      0.31      0.18        16
#            6       0.27      0.44      0.34        27
#            7       0.74      0.72      0.73        39
#            8       0.15      0.11      0.13        96
#            9       0.40      0.17      0.23       103
#           10       0.08      0.03      0.04        78
#           11       0.24      0.30      0.26        30
#           12       0.18      0.12      0.15       338
#           13       0.10      0.06      0.07       163
#           14       0.00      0.00      0.00        13
#           15       0.24      0.12      0.16        33
#           16       0.07      0.11      0.08        74
#           17       0.22      0.16      0.19        98
#           18       0.25      0.07      0.11        41
#           19       0.10      0.17      0.12        12
#           20       0.24      0.41      0.30        51
#           21       0.04      0.35      0.08        68
#           22       0.37      0.35      0.36       106
#           23       0.00      0.00      0.00        35
#           24       0.31      0.41      0.35        70
#           25       0.23      0.11      0.14        47
#           26       0.18      0.16      0.17       154
#           27       0.24      0.37      0.29       120
#           28       0.44      0.25      0.32        16
#           29       0.00      0.00      0.00        30
#           30       0.52      0.16      0.25       246
#
#     accuracy                           0.21      2500
#    macro avg       0.24      0.23      0.22      2500
# weighted avg       0.26      0.21      0.22      2500
#
# {'eval_loss': 3.1255385875701904, 'eval_accuracy': 0.21, 'eval_f1': 0.2150025009172042, 'eval_precision': 0.2649141779566723, 'eval_recall': 0.21, 'eval_runtime': 43.4584, 'eval_samples_per_second': 57.526, 'test_mem_cpu_alloc_delta': 432606, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 503958, 'test_mem_gpu_peaked_delta': 774225408}

# %%
#Test Dato español  

path3 = "amazonES_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_ES)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Oranges',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.23      0.19      0.21        75
#            1       0.20      0.19      0.20        93
#            2       0.18      0.08      0.11        49
#            3       0.19      0.28      0.23        78
#            4       0.60      0.46      0.52        61
#            5       0.33      0.30      0.31        44
#            6       0.46      0.52      0.49        21
#            7       0.00      0.00      0.00        59
#            8       0.04      0.05      0.04       136
#            9       0.02      0.02      0.02        57
#           10       0.00      0.00      0.00        16
#           11       0.19      0.03      0.05       354
#           12       0.06      0.11      0.07       146
#           13       0.00      0.00      0.00        21
#           14       0.00      0.00      0.00        30
#           15       0.00      0.00      0.00        87
#           16       0.04      0.12      0.06        52
#           17       0.00      0.00      0.00        44
#           18       0.00      0.00      0.00        15
#           19       0.00      0.00      0.00        58
#           20       0.00      0.00      0.00        40
#           21       0.06      0.15      0.09       151
#           22       0.00      0.00      0.00        37
#           23       0.00      0.00      0.00        52
#           24       0.00      0.00      0.00        28
#           25       0.00      0.00      0.00       185
#           26       0.07      0.05      0.06       166
#           27       0.01      0.14      0.02        22
#           28       0.00      0.00      0.00        19
#           29       0.00      0.00      0.00       304
#           30       0.00      0.00      0.00         0
#
#     accuracy                           0.07      2500
#    macro avg       0.09      0.09      0.08      2500
# weighted avg       0.09      0.07      0.07      2500
#
# {'eval_loss': 4.8127665519714355, 'eval_accuracy': 0.074, 'eval_f1': 0.07035992986357052, 'eval_precision': 0.09002302782958024, 'eval_recall': 0.074, 'eval_runtime': 43.6481, 'eval_samples_per_second': 57.276, 'test_mem_cpu_alloc_delta': 429164, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 509600, 'test_mem_gpu_peaked_delta': 774225408}

# %%
#Test Dato frances  

path3 = "amazonFR_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_FR = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_FR)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Greens',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.21      0.21      0.21        72
#            1       0.19      0.17      0.18        78
#            2       0.17      0.03      0.05        62
#            3       0.31      0.31      0.31        98
#            4       0.81      0.52      0.64       103
#            5       0.16      0.19      0.18        26
#            6       0.37      0.76      0.50        17
#            7       0.00      0.00      0.00        79
#            8       0.03      0.04      0.04       112
#            9       0.02      0.02      0.02        59
#           10       0.00      0.00      0.00        13
#           11       0.22      0.06      0.10       365
#           12       0.08      0.14      0.10       146
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00        34
#           15       0.00      0.00      0.00       100
#           16       0.04      0.08      0.05        64
#           17       0.00      0.00      0.00        31
#           18       0.00      0.00      0.00        21
#           19       0.00      0.00      0.00        72
#           20       0.04      0.06      0.05        48
#           21       0.05      0.14      0.08       133
#           22       0.01      0.02      0.01        41
#           23       0.00      0.00      0.00        68
#           24       0.02      0.07      0.03        27
#           25       0.00      0.00      0.00        97
#           26       0.00      0.00      0.00       164
#           27       0.02      0.23      0.03        22
#           28       0.00      0.00      0.00        11
#           29       1.00      0.00      0.01       321
#           30       0.00      0.00      0.00         0
#
#     accuracy                           0.09      2500
#    macro avg       0.12      0.10      0.08      2500
# weighted avg       0.24      0.09      0.09      2500
#
# {'eval_loss': 4.831036567687988, 'eval_accuracy': 0.0872, 'eval_f1': 0.08673070378432572, 'eval_precision': 0.2377986938003525, 'eval_recall': 0.0872, 'eval_runtime': 43.5562, 'eval_samples_per_second': 57.397, 'test_mem_cpu_alloc_delta': 433758, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 507168, 'test_mem_gpu_peaked_delta': 774225408}

# %% [markdown]
# ## Save Model

# %%
# !ls drive/MyDrive/TFG_1/Modelos_entrenados/

# %%
# saving the fine tuned model & tokenizer
model_path = "drive/MyDrive/TFG_1/Modelos_entrenados/Category_text_mBERT"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %% [markdown]
# # BertForSequenceClassification - CATEGORÍA
#
# - Clasificación de categorias de productos a partir del review_body + titulo

# %%
RANDOM_SEED=8
MAX_LENGTH=260


## CLASES DEL CLASIFICADOR 

class_names = df_train.product_category.unique().tolist()

# %%
#TOKENIZAMOS LOS DATAFRAMES

train_encodings = tokenizer(df_train.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

val_encodings = tokenizer(df_valid.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

# %%
class GPReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_labels = df_train.product_category_cod.values
val_labels = df_valid.product_category_cod.values
test_labels = df_test.product_category_cod.values

# %%
train_data = GPReviewDataset(train_encodings, torch.from_numpy(train_labels))
val_data = GPReviewDataset(val_encodings, torch.from_numpy(val_labels))
test_data = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

# %%
model = BertForSequenceClassification.from_pretrained(
    PRE_TRAINED_MODEL_NAME, # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = len(class_names), # The number of output labels--2 for binary classification.  si pones num_labels=1 hace MSE LOSS
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False ,# Whether the model returns all hidden-states.   
    vocab_size=tokenizer.vocab_size)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %% [markdown]
# ## Training

# %%
model_dir="./"

from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = model_dir +  'prueba/results',          # output directory
    overwrite_output_dir = True,
    evaluation_strategy='epoch',
    num_train_epochs=3,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir = model_dir +  'prueba/logs',            # directory for storing logs
    logging_steps=10,
    load_best_model_at_end = True,
    #report_to = 'wandb',           # enable logging to W&B
    run_name = 'EN-body_title - category'   # name of the W&B run
)


trainer = Trainer(
    model = model,                         # the instantiated 🤗 Transformers model to be trained
    args = training_args,                  # training arguments, defined above
    train_dataset = train_data,         # training dataset
    eval_dataset = val_data,
    compute_metrics = compute_metrics            # evaluation dataset
)

trainer.train()
# Out:
# wandb: wandb version 0.10.24 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">EN-body_title - category</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT</a><br/>
#                 Run page: <a href="https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/2c0wgpn3" target="_blank">https://wandb.ai/lucialarraona/RATING%20CLASSIFICATION%20mBERT/runs/2c0wgpn3</a><br/>
#                 Run data is saved locally in <code>/home/nlpbert/notebooks/wandb/run-20210402_095144-2c0wgpn3</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='18750' max='18750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18750/18750 9:46:16, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.608800</td>
#       <td>1.779407</td>
#       <td>0.500800</td>
#       <td>0.488086</td>
#       <td>0.503644</td>
#       <td>0.500800</td>
#       <td>44.200100</td>
#       <td>56.561000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.561500</td>
#       <td>1.659835</td>
#       <td>0.522400</td>
#       <td>0.512957</td>
#       <td>0.519077</td>
#       <td>0.522400</td>
#       <td>43.921000</td>
#       <td>56.920000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.453400</td>
#       <td>1.647056</td>
#       <td>0.533200</td>
#       <td>0.523036</td>
#       <td>0.528922</td>
#       <td>0.533200</td>
#       <td>43.907600</td>
#       <td>56.938000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18750, training_loss=1.6740030372111003, metrics={'train_runtime': 35180.5629, 'train_samples_per_second': 0.533, 'total_flos': 1.66493133144e+17, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 69622, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 40834375, 'train_mem_gpu_alloc_delta': 2885237248, 'train_mem_cpu_peaked_delta': 734433632, 'train_mem_gpu_peaked_delta': 3937049088})

# %%
model_path = "Chek1mv_multi5"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('Chek1mv_multi5/tokenizer_config.json',
#  'Chek1mv_multi5/special_tokens_map.json',
#  'Chek1mv_multi5/vocab.txt',
#  'Chek1mv_multi5/added_tokens.json')

# %% [markdown]
# ## Evaluation inglés

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='120' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 07:35]
#     </div>
# wandb: WARNING Step must only increase in log calls.  Step 18750 < 18751; dropping {'eval/loss': 1.6470561027526855, 'eval/accuracy': 0.5332, 'eval/f1': 0.52303597433921, 'eval/precision': 0.5289224713480125, 'eval/recall': 0.5332, 'eval/runtime': 43.3442, 'eval/samples_per_second': 57.678, 'train/epoch': 3.0}.
# {'eval_loss': 1.6470561027526855,
#  'eval_accuracy': 0.5332,
#  'eval_f1': 0.52303597433921,
#  'eval_precision': 0.5289224713480125,
#  'eval_recall': 0.5332,
#  'eval_runtime': 43.3442,
#  'eval_samples_per_second': 57.678,
#  'epoch': 3.0,
#  'eval_mem_cpu_alloc_delta': 439597,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 492638,
#  'eval_mem_gpu_peaked_delta': 774225408}

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Aleman 
path3 = "amazonDE_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

predictions,labels, metrics = trainer.predict(test_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Blues',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.23      0.25       114
#            1       0.19      0.18      0.18        62
#            2       0.45      0.17      0.24        54
#            3       0.41      0.38      0.39       111
#            4       0.34      0.53      0.41        55
#            5       0.14      0.38      0.21        16
#            6       0.29      0.52      0.37        27
#            7       0.68      0.77      0.72        39
#            8       0.14      0.10      0.12        96
#            9       0.28      0.10      0.14       103
#           10       0.07      0.01      0.02        78
#           11       0.20      0.37      0.26        30
#           12       0.20      0.16      0.18       338
#           13       0.14      0.08      0.10       163
#           14       0.00      0.00      0.00        13
#           15       0.19      0.12      0.15        33
#           16       0.07      0.16      0.10        74
#           17       0.28      0.24      0.26        98
#           18       0.21      0.07      0.11        41
#           19       0.14      0.25      0.18        12
#           20       0.20      0.37      0.26        51
#           21       0.06      0.49      0.10        68
#           22       0.47      0.34      0.40       106
#           23       0.00      0.00      0.00        35
#           24       0.56      0.44      0.50        70
#           25       0.33      0.13      0.18        47
#           26       0.24      0.16      0.19       154
#           27       0.28      0.34      0.31       120
#           28       0.58      0.44      0.50        16
#           29       0.00      0.00      0.00        30
#           30       0.57      0.13      0.21       246
#
#     accuracy                           0.22      2500
#    macro avg       0.26      0.25      0.23      2500
# weighted avg       0.28      0.22      0.22      2500
#
# {'eval_loss': 3.1982550621032715, 'eval_accuracy': 0.216, 'eval_f1': 0.2190285182737182, 'eval_precision': 0.2805312334644226, 'eval_recall': 0.216, 'eval_runtime': 43.3627, 'eval_samples_per_second': 57.653, 'test_mem_cpu_alloc_delta': 434290, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 504895, 'test_mem_gpu_peaked_delta': 774225408}

# %%
#Test Dato español  

path3 = "amazonES_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_ES)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Oranges',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.16      0.19        75
#            1       0.26      0.17      0.21        93
#            2       0.30      0.14      0.19        49
#            3       0.15      0.31      0.21        78
#            4       0.48      0.49      0.49        61
#            5       0.26      0.23      0.24        44
#            6       0.48      0.62      0.54        21
#            7       0.00      0.00      0.00        59
#            8       0.03      0.06      0.04       136
#            9       0.02      0.02      0.02        57
#           10       0.00      0.00      0.00        16
#           11       0.14      0.04      0.07       354
#           12       0.08      0.15      0.10       146
#           13       0.00      0.00      0.00        21
#           14       0.00      0.00      0.00        30
#           15       0.00      0.00      0.00        87
#           16       0.03      0.12      0.05        52
#           17       0.03      0.05      0.03        44
#           18       0.00      0.00      0.00        15
#           19       0.00      0.00      0.00        58
#           20       0.00      0.00      0.00        40
#           21       0.07      0.11      0.08       151
#           22       0.00      0.00      0.00        37
#           23       0.00      0.00      0.00        52
#           24       0.03      0.04      0.03        28
#           25       0.15      0.02      0.03       185
#           26       0.05      0.04      0.04       166
#           27       0.00      0.05      0.01        22
#           28       0.00      0.00      0.00        19
#           29       0.00      0.00      0.00       304
#           30       0.00      0.00      0.00         0
#
#     accuracy                           0.08      2500
#    macro avg       0.09      0.09      0.08      2500
# weighted avg       0.09      0.08      0.07      2500
#
# {'eval_loss': 4.767122268676758, 'eval_accuracy': 0.0772, 'eval_f1': 0.07422456273484075, 'eval_precision': 0.09462465450509232, 'eval_recall': 0.0772, 'eval_runtime': 43.784, 'eval_samples_per_second': 57.098, 'test_mem_cpu_alloc_delta': 436672, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 501341, 'test_mem_gpu_peaked_delta': 774225408}

# %%
#Test Dato frances  

path3 = "amazonFR_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_FR = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

## predicciones sobre valid data en ESPAÑOL
predictions,labels, metrics = trainer.predict(test_data_FR)  

# MATRIZ DE CONFUSION
matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Greens',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.23      0.19      0.21        72
#            1       0.22      0.18      0.20        78
#            2       0.40      0.10      0.16        62
#            3       0.23      0.35      0.27        98
#            4       0.75      0.57      0.65       103
#            5       0.09      0.12      0.10        26
#            6       0.47      0.88      0.61        17
#            7       0.00      0.00      0.00        79
#            8       0.03      0.04      0.03       112
#            9       0.00      0.00      0.00        59
#           10       0.00      0.00      0.00        13
#           11       0.24      0.05      0.09       365
#           12       0.07      0.14      0.09       146
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00        34
#           15       0.00      0.00      0.00       100
#           16       0.03      0.08      0.04        64
#           17       0.00      0.00      0.00        31
#           18       0.00      0.00      0.00        21
#           19       0.00      0.00      0.00        72
#           20       0.02      0.02      0.02        48
#           21       0.07      0.13      0.09       133
#           22       0.00      0.00      0.00        41
#           23       0.00      0.00      0.00        68
#           24       0.00      0.00      0.00        27
#           25       0.25      0.01      0.02        97
#           26       0.02      0.01      0.02       164
#           27       0.02      0.36      0.05        22
#           28       0.00      0.00      0.00        11
#           29       1.00      0.01      0.01       321
#           30       0.00      0.00      0.00         0
#
#     accuracy                           0.09      2500
#    macro avg       0.13      0.10      0.09      2500
# weighted avg       0.25      0.09      0.09      2500
#
# {'eval_loss': 4.834456920623779, 'eval_accuracy': 0.09, 'eval_f1': 0.08763001099040939, 'eval_precision': 0.25101884562380367, 'eval_recall': 0.09, 'eval_runtime': 44.031, 'eval_samples_per_second': 56.778, 'test_mem_cpu_alloc_delta': 426199, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 510955, 'test_mem_gpu_peaked_delta': 774225408}

# %%
## Función test dato  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# El metodo predict devuelve array con predicciones, las labels del test data y las métricas del test

#Inglés
path3 = "amazonEN_test.csv"
df_test = pd.read_csv(path3)
df_test = df_test

test_encodings = tokenizer(df_test.text_title.values.tolist(), #truncation=True, padding=True,
      add_special_tokens=True,
      truncation=True,
      max_length=MAX_LENGTH,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt')

test_labels = df_test.product_category_cod.values
test_data_ES = GPReviewDataset(test_encodings, torch.from_numpy(test_labels))

predictions,labels, metrics = trainer.predict(test_data)  

matrix = confusion_matrix(labels, predictions.argmax(axis=1))

plt.figure(figsize = (20,10))
## Confusion matrix with counts
sns.heatmap(matrix, annot=True,cmap='Purples',fmt='g')

#sns.heatmap(matrix/np.sum(matrix), annot=True, 
#          fmt='.2%', cmap='Oranges')
plt.xlabel("Predicted class")
plt.ylabel("True class") 

clas_report = classification_report(labels, predictions.argmax(axis=1))

print(clas_report)
print(metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.23      0.25       114
#            1       0.19      0.18      0.18        62
#            2       0.45      0.17      0.24        54
#            3       0.41      0.38      0.39       111
#            4       0.34      0.53      0.41        55
#            5       0.14      0.38      0.21        16
#            6       0.29      0.52      0.37        27
#            7       0.68      0.77      0.72        39
#            8       0.14      0.10      0.12        96
#            9       0.28      0.10      0.14       103
#           10       0.07      0.01      0.02        78
#           11       0.20      0.37      0.26        30
#           12       0.20      0.16      0.18       338
#           13       0.14      0.08      0.10       163
#           14       0.00      0.00      0.00        13
#           15       0.19      0.12      0.15        33
#           16       0.07      0.16      0.10        74
#           17       0.28      0.24      0.26        98
#           18       0.21      0.07      0.11        41
#           19       0.14      0.25      0.18        12
#           20       0.20      0.37      0.26        51
#           21       0.06      0.49      0.10        68
#           22       0.47      0.34      0.40       106
#           23       0.00      0.00      0.00        35
#           24       0.56      0.44      0.50        70
#           25       0.33      0.13      0.18        47
#           26       0.24      0.16      0.19       154
#           27       0.28      0.34      0.31       120
#           28       0.58      0.44      0.50        16
#           29       0.00      0.00      0.00        30
#           30       0.57      0.13      0.21       246
#
#     accuracy                           0.22      2500
#    macro avg       0.26      0.25      0.23      2500
# weighted avg       0.28      0.22      0.22      2500
#
# {'eval_loss': 3.1982550621032715, 'eval_accuracy': 0.216, 'eval_f1': 0.2190285182737182, 'eval_precision': 0.2805312334644226, 'eval_recall': 0.216, 'eval_runtime': 43.689, 'eval_samples_per_second': 57.223, 'test_mem_cpu_alloc_delta': 425811, 'test_mem_gpu_alloc_delta': 0, 'test_mem_cpu_peaked_delta': 508602, 'test_mem_gpu_peaked_delta': 774225408}

# %% [markdown]
# ## Save Model

# %%
# !ls drive/MyDrive/TFG_1/Modelos_entrenados/

# %%
# saving the fine tuned model & tokenizer
model_path = "drive/MyDrive/TFG_1/Modelos_entrenados/Category_text_title_mBERT"
trainer.save_model(model_path)
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
